# %% [markdown]
# Открытие гугл диска

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
import os.path
from PIL import Image
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import random
from torchvision import transforms
import math
import torch.nn as nn
import torch.nn.functional as F
import time
from torch.amp import autocast, GradScaler

# %% [markdown]
# Дата лоадер

# %%
import torchvision.transforms.functional as TF
import random

# %%
def get_pathes(base_folder ):
    paths = []
    for i in range(11):
        folder_name = f'{i:02d}'
        image_folder = os.path.join(base_folder, folder_name, 'image_0')
        movements_file = os.path.join(base_folder, folder_name, f'{folder_name}.txt')
        paths.append((image_folder,movements_file))
    return paths

def get_data(batch_size, base_folder = '/content/drive/MyDrive'):
    paths = get_pathes(base_folder)

    # Выбор папок для тренировочных, валидационных и тестовых данных
    validation_folder = paths[-2]  # Предпоследняя папка
    test_folder = paths[-1]        # Последняя папка
    train_folders = paths[:-2]     # Все остальные папки

    # Чтение движений из файла
    def create_movements(movements_file):
        movements = []
        with open(movements_file, 'r') as f:
            for line in f:
                data = list(map(float, line.strip().split()))
                movements.append(data)
        return movements

    # movements = create_movements(movements_file)

    # Преобразование движений
    # def transform_mov(movements):
    #     new_movements = []
    #     for matrix in movements:
    #         new_matrix = [
    #             matrix[0:4],
    #             matrix[4:8],
    #             matrix[8:12],
    #             [0, 0, 0, 1]
    #         ]
    #         new_matrix = torch.tensor(new_matrix, dtype=torch.float32)
    #         new_movements.append(new_matrix)

    #     res_movements = []
    #     for i in range(len(new_movements) - 1):
    #         T1_inv = torch.linalg.inv(new_movements[i])
    #         T_rel = torch.matmul(new_movements[i + 1], T1_inv)
    #         res_matrix = T_rel[:3]
    #         res_matrix = torch.cat([res_matrix[0], res_matrix[1], res_matrix[2]])
    #         res_movements.append(res_matrix)


    #     return res_movements

    # def transform_mov(movements):
    #     res_movements = []
    #     for i in range(len(movements)-1):
    #         m1 = torch.tensor(movements[i])
    #         m2 = torch.tensor(movements[i+1])
    #         res = m2-m1
    #         res_movements.append(res)
    #     return res_movements
    step = 1

    def transform_mov(movements):
        res_movements = []
        # for i in range(len(movements)-1):
        for i in range(len(movements)-step):
            m1 = torch.tensor(movements[i])
            m2 = torch.tensor(movements[i+step])
            res = m2-m1
            distance = math.sqrt(pow(res[3],2) + pow(res[7],2) + pow(res[11],2))
            res_movements.append([distance ])
        return res_movements



    # movements = transform_mov(movements)

    # class PairTransform:
    #     def __init__(self):
    #         self.crop_size = (370, 1226)

    #     def __call__(self, image1, image2):
    #         # Случайный кроп
    #         i, j, h, w = transforms.RandomResizedCrop.get_params(
    #             image1, scale=(0.9, 1.0), ratio=(1.0, 1.0)
    #         )
    #         image1 = TF.resized_crop(image1, i, j, h, w, self.crop_size)
    #         image2 = TF.resized_crop(image2, i, j, h, w, self.crop_size)

    #         # Случайный поворот по горизонтали
    #         if random.random() > 0.5:
    #             image1 = TF.hflip(image1)
    #             image2 = TF.hflip(image2)

    #         # Яркость и контраст
    #         brightness_factor = random.uniform(0.8, 1.2)
    #         contrast_factor = random.uniform(0.8, 1.2)

    #         image1 = TF.adjust_brightness(image1, brightness_factor)
    #         image2 = TF.adjust_brightness(image2, brightness_factor)

    #         image1 = TF.adjust_contrast(image1, contrast_factor)
    #         image2 = TF.adjust_contrast(image2, contrast_factor)

    #         # Grayscale + ToTensor
    #         image1 = TF.to_tensor(TF.to_grayscale(image1))
    #         image2 = TF.to_tensor(TF.to_grayscale(image2))

    #         return image1, image2


    # Оптимизированный класс Dataset
    class ImageDataset(Dataset):
        def __init__(self, image_folder, movements, transform=None ):
            # Получаем список всех файлов .png и сортируем их
            all_image_files = sorted([os.path.join(image_folder, file) for file in os.listdir(image_folder) if file.endswith('.png')])
            self.image_files = all_image_files
            self.movements = movements
            self.transform = transform

        def __len__(self):
            # Возвращаем минимальную длину между движениями и изображениями - 1
            return min(len(self.movements), len(self.image_files) - 1)


        def __getitem__(self, idx):
            image1_path = self.image_files[idx]
            # image2_path = self.image_files[idx + 1]
            image2_path = self.image_files[idx + step]

            image1 = Image.open(image1_path).convert('L')
            image2 = Image.open(image2_path).convert('L')

            if self.transform:
                image1 = self.transform(image1)
                image2 = self.transform(image2)

            # if self.transform:
            #     image1,image2 = self.transform(image1,image2)

            movement = self.movements[idx].clone().detach().float()if isinstance(self.movements[idx], torch.Tensor) else torch.tensor(self.movements[idx], dtype=torch.float32)
            return (image1, image2), movement


    # Трансформации для уменьшения использования памяти
    transform = transforms.Compose([
        transforms.Grayscale(),
        # transforms.Resize((376,1240)),
        transforms.CenterCrop((370,1226)),
        # transforms.Resize((180,320)),
        transforms.ToTensor()
    ])

    # transform = PairTransform()

    def load_dataset(folders):
        images, movements = [], []
        for image_folder, movements_file in folders:
            mov = create_movements(movements_file)
            mov = transform_mov(mov)
            movements.append(mov)
            images.append(image_folder)
        return images, movements

    train_images, train_movements = load_dataset(train_folders)
    train_dataset = []
    for index,image_folder in enumerate(train_images):
        dataset = ImageDataset(image_folder, train_movements[index], transform=transform)
        train_dataset.append(dataset)
    train_dataset = torch.utils.data.ConcatDataset(train_dataset)

    # Загрузка валидационных данных
    val_images, val_movements = load_dataset([validation_folder])
    val_dataset = ImageDataset(val_images[0], val_movements[0], transform=transform)


   # Загрузка тестовых данных
    test_images, test_movements = load_dataset([test_folder])
    test_dataset = ImageDataset(test_images[0], test_movements[0], transform=transform)

    # DataLoaders
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle = True, num_workers=4, pin_memory=True)
    validation_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle = False, num_workers=4, pin_memory=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle = False, num_workers=4, pin_memory=True)

    return train_loader, validation_loader, test_loader

# %% [markdown]
# EVALUATION

# %%
def set_all_seeds(seed):
    os.environ["PL_GLOBAL_SEED"] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

def compute_accuracy(model, data_loader, device):
    model.eval()
    total_loss = 0.0
    num_batches = 0
    correct_predictions = 0   # Счетчик корректных предсказаний
    total_samples = 0         # Общее количество элементов

    criterion = torch.nn.MSELoss()

    with torch.no_grad():
        for batch_idx, ((feature1, feature2),targets) in enumerate(data_loader):
            feature1 = feature1.to(device)
            feature2 = feature2.to(device)
            targets = targets.to(device)
            with autocast(device_type='cuda'):
                predicted_y = model(feature1, feature2)

            # Вычисление ошибки
            loss = criterion(predicted_y, targets)
            total_loss += loss.item()
            num_batches += 1

            # Проверка критерия качества
            relative_difference = torch.abs((predicted_y - targets))  # Расчет абсолютного отклонения
            valid_predictions = torch.all(relative_difference <= 0.1, dim=1)    # Условие: отклонение <= 10 см
            correct_predictions += torch.sum(valid_predictions).item()
            total_samples = total_samples + targets.size(0)


    avg_loss = total_loss / num_batches             # Расчет средней ошибки
    accuracy = correct_predictions / total_samples  # Расчет доли верных предсказаний
    return avg_loss, accuracy

def compute_accuracy1(model, data_loader, device):
    model.eval()
    total_loss = 0.0
    num_batches = 0
    correct_predictions = 0   # Счетчик корректных предсказаний
    total_samples = 0         # Общее количество элементов

    criterion = torch.nn.MSELoss()

    with torch.no_grad():
        for batch_idx, ((feature1, feature2),targets) in enumerate(data_loader):
            feature1 = feature1.to(device)
            feature2 = feature2.to(device)
            targets = targets.to(device)
            with autocast(device_type='cuda'):
                predicted_y = model(feature1, feature2)
            if 0 <= batch_idx < 1:
                print(f"Predicted: {predicted_y} \n, real: {targets}")
            # Вычисление ошибки
            loss = criterion(predicted_y, targets)
            total_loss += loss.item()
            num_batches += 1

            # Проверка критерия качества
            relative_difference = torch.abs((predicted_y - targets))  # Расчет абсолютного отклонения
            valid_predictions = torch.all(relative_difference <= 0.1, dim=1)    # Условие: отклонение <= 10 см
            correct_predictions += torch.sum(valid_predictions).item()
            total_samples = total_samples + targets.size(0)


    avg_loss = total_loss / num_batches             # Расчет средней ошибки
    accuracy = correct_predictions / total_samples  # Расчет доли верных предсказаний
    return avg_loss, accuracy

# %% [markdown]
# Model

# %%
import torch
import torch.nn as nn
from torchvision.models import resnet50, ResNet50_Weights

# %%
class Network(nn.Module):
    def __init__(self):
        super().__init__()

        # Загружаем предобученный ResNet101
        weights = ResNet50_Weights.DEFAULT
        base_model = resnet50(weights=weights)

        # Заменяем первый conv слой для 1-канального изображения
        self.backbone = nn.Sequential()
        conv1 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False)
        # Копируем и усредняем веса по каналам
        with torch.no_grad():
            conv1.weight[:] = base_model.conv1.weight.mean(dim=1, keepdim=True)
        self.backbone.add_module("conv1", conv1)

        # Добавляем остальные блоки ResNet до avgpool (исключая fc)
        for name, module in list(base_model.named_children())[1:-2]:
            self.backbone.add_module(name, module)

        # Размерность последовательности: [B, 2048, 12, 39] → [B, 468, 2048]
        # self.lstm = nn.LSTM(
        #     input_size=2048,
        #     hidden_size=hidden_size,
        #     num_layers=num_layers,
        #     batch_first=True,
        #     bidirectional=bidirectional
        # )
        for param in self.backbone.parameters():
            param.requires_grad = False

        self.lstm1 = nn.LSTMCell(input_size = 2048*3*1, hidden_size=128)
        self.lstm2 = nn.LSTMCell(input_size = 2048*3*1, hidden_size=128)

        self.classifier = nn.Linear(128, 1)

    # def forward(self, x):
    #     # x: [B, 1, 370, 1226]
    #     x = self.backbone(x)              # [B, 2048, 12, 39]
    #     x = x.permute(0, 2, 3, 1)         # [B, 12, 39, 2048]
    #     x = x.reshape(x.size(0), -1, 2048)  # [B, 468, 2048]
    #     lstm_out, _ = self.lstm(x)        # [B, 468, hidden]
    #     out = self.classifier(lstm_out[:, -1, :])  # финальный временной шаг
    #     return out

    def forward(self,image1,image2):
        out_features1 = self.backbone(image1)
        out_features2 = self.backbone(image2)

        out_features1 = torch.nn.functional.adaptive_avg_pool2d(out_features1, (1, 3))  # [B, C, 3, 10]
        out_features1 = out_features1.view(out_features1.size(0), -1)  # [B, C * 3 * 10]

        out_features2 = torch.nn.functional.adaptive_avg_pool2d(out_features2, (1, 3))
        out_features2 = out_features2.view(out_features2.size(0), -1)
        batch_size = out_features1.size(0)

        # Инициализируем скрытые состояния и состояния ячеек для lstm1
        h_t1 = torch.zeros(batch_size, self.lstm1.hidden_size, device=out_features1.device)
        c_t1 = torch.zeros(batch_size, self.lstm1.hidden_size, device=out_features1.device)

        # Пропускаем признаки первой картинки через lstm1 (один временной шаг)
        h_t1_next, c_t1_next = self.lstm1(out_features1, (h_t1, c_t1))
        h_t2_next, c_t2_next = self.lstm2(out_features2, (h_t1_next, c_t1_next))
        out = self.classifier(h_t2_next) # [batch_size, 1]
        return out

# %% [markdown]
# Train

# %%
def train(model, num_epochs, last_epoch, train_loader,
                validation_loader, test_loader,optimizer, device,scheduler,
          checkpoint_dict,scaler):
    start_time = time.time()
    minibatch_loss_list, train_loss_list, valid_loss_list = [] ,[], []
    criterion = torch.nn.MSELoss()

    for epoch in range(last_epoch, num_epochs):
        model.train()
        for batch_idx,((feature1,feature2),targets) in enumerate(train_loader):
            feature1 = feature1.to(device)
            feature2 = feature2.to(device)
            targets = targets.to(device)

            optimizer.zero_grad()
            # <<< Mixed precision begins
            with autocast(device_type='cuda'):
                predicted_y = model(feature1,feature2)
                loss = criterion(predicted_y, targets)

            #  Зворотній прохід
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            minibatch_loss_list.append(loss.item())
            if batch_idx %100 == 0:
                print(f'Epoch: {epoch+1:03d}/{num_epochs:03d} '
                      f'| Batch {batch_idx:04d}/{len(train_loader):04d} '
                      f'| Loss: {loss:.4f}'
                      f'| Learning rate: {optimizer.param_groups[0]["lr"]}')
        # scheduler.step()
        model.eval()
        with torch.no_grad():
            avg_loss_train, accuracy_train = compute_accuracy1(model, train_loader, device)
            avg_loss_val, accuracy_val = compute_accuracy1(model, validation_loader, device)
            # scheduler.step( avg_loss_val)
            print(f'Epoch: {epoch+1:03d}/{num_epochs:03d} '
                  f'| Train AVG LOSS: {avg_loss_train: .4f} | Accuracy_train: {accuracy_train: .4f} \n'
                  f'| Validation AVG LOSS: {avg_loss_val: .4f} | Accuracy_val: {accuracy_val: .4f} ')
            train_loss_list.append(avg_loss_train)
            valid_loss_list.append(avg_loss_val)

        scheduler.step()

        # checkpoint = {
        #     'model_state_dict': model.state_dict(),
        #     'optimizer_state_dict': optimizer.state_dict()
        # }

        checkpoint_dict['state_model'] = model.state_dict()
        checkpoint_dict['state_opt'] =  optimizer.state_dict()
        checkpoint_dict[ 'state_scheduler'] = scheduler.state_dict()
        checkpoint_dict['train_loss'] = avg_loss_train
        checkpoint_dict['val_loss'] = avg_loss_val
        checkpoint_dict['train_acc'] = accuracy_train
        checkpoint_dict['val_acc'] =  accuracy_val
        checkpoint_dict['EPOCHS'] = num_epochs
        checkpoint_dict['current_epoch'] = epoch + 1
        checkpoint_dict[ 'learning'] = optimizer.param_groups[0]["lr"]

        path = directory_path + str(epoch + 1) + '_epoch.pth'
        torch.save(checkpoint_dict, path)
        # path = '/content/drive/My Drive/checkpoint_model_3.pth'
        # torch.save(checkpoint, path)

        elapsed = (time.time() - start_time)/60
        print(f'Time elapsed: {elapsed:.2f} min')

    elapsed = (time.time() - start_time)/60
    print(f'Total Training Time: {elapsed:.2f} min')

    avg_loss_test, accuracy_test = compute_accuracy(model, test_loader,device)
    print(f'Test AVG LOSS: {avg_loss_test: .4f} | Accuracy_test: {accuracy_test: .4f}')

    return minibatch_loss_list, train_loss_list, valid_loss_list

# %% [markdown]
# Описание модели, оптимизатора, шедулера

# %%
txt_model_opt_shed = '''
class Network(nn.Module):
    def __init__(self):
        super().__init__()

        # Загружаем предобученный ResNet101
        weights = ResNet50_Weights.DEFAULT
        base_model = resnet50(weights=weights)

        # Заменяем первый conv слой для 1-канального изображения
        self.backbone = nn.Sequential()
        conv1 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False)
        # Копируем и усредняем веса по каналам
        with torch.no_grad():
            conv1.weight[:] = base_model.conv1.weight.mean(dim=1, keepdim=True)
        self.backbone.add_module("conv1", conv1)

        # Добавляем остальные блоки ResNet до avgpool (исключая fc)
        for name, module in list(base_model.named_children())[1:-2]:
            self.backbone.add_module(name, module)

        # Размерность последовательности: [B, 2048, 12, 39] → [B, 468, 2048]
        # self.lstm = nn.LSTM(
        #     input_size=2048,
        #     hidden_size=hidden_size,
        #     num_layers=num_layers,
        #     batch_first=True,
        #     bidirectional=bidirectional
        # )

        self.lstm1 = nn.LSTMCell(input_size = 2048*3*1, hidden_size=128)
        self.lstm2 = nn.LSTMCell(input_size = 2048*3*1, hidden_size=128)

        self.classifier = nn.Linear(128, 1)

    # def forward(self, x):
    #     # x: [B, 1, 370, 1226]
    #     x = self.backbone(x)              # [B, 2048, 12, 39]
    #     x = x.permute(0, 2, 3, 1)         # [B, 12, 39, 2048]
    #     x = x.reshape(x.size(0), -1, 2048)  # [B, 468, 2048]
    #     lstm_out, _ = self.lstm(x)        # [B, 468, hidden]
    #     out = self.classifier(lstm_out[:, -1, :])  # финальный временной шаг
    #     return out

    def forward(self,image1,image2):
        out_features1 = self.backbone(image1)
        out_features2 = self.backbone(image2)

        out_features1 = torch.nn.functional.adaptive_avg_pool2d(out_features1, (1, 3))  # [B, C, 3, 10]
        out_features1 = out_features1.view(out_features1.size(0), -1)  # [B, C * 3 * 10]

        out_features2 = torch.nn.functional.adaptive_avg_pool2d(out_features2, (1, 3))
        out_features2 = out_features2.view(out_features2.size(0), -1)
        batch_size = out_features1.size(0)

        # Инициализируем скрытые состояния и состояния ячеек для lstm1
        h_t1 = torch.zeros(batch_size, self.lstm1.hidden_size, device=out_features1.device)
        c_t1 = torch.zeros(batch_size, self.lstm1.hidden_size, device=out_features1.device)

        # Пропускаем признаки первой картинки через lstm1 (один временной шаг)
        h_t1_next, c_t1_next = self.lstm1(out_features1, (h_t1, c_t1))
        h_t2_next, c_t2_next = self.lstm2(out_features2, (h_t1_next, c_t1_next))
        out = self.classifier(h_t2_next) # [batch_size, 1]
        return out

optimizer = torch.optim.Adam(model.parameters(), lr = 0.0001, weight_decay = 0.0001)

'''

# %% [markdown]
# Создание библиотеки для хранения сохранения

# %%
directory_path = '/content/drive/My Drive/checpoint/model_resnet-50_lstm/'

# Проверка существования директории
if not os.path.exists(directory_path):
    # Создание директории
    os.makedirs(directory_path)
    print(f"Директория {directory_path} была создана.")
else:
    print(f"Директория {directory_path} уже существует.")
# Out:
# Директория /content/drive/My Drive/checpoint/model_resnet-50_lstm/ была создана.

# %% [markdown]
# Создание словаря для сохранения результатов

# %%
checkpoint_dict = {
    'model_description' : txt_model_opt_shed,
    'state_model' : None,
    'state_opt'   : None,
    'state_scheduler' : None,

    'train_loss' :None,
    'val_loss'   : None,
    'best_loss'  : None,
    'train_acc'  : None,
    'val_acc'    : None,

    'EPOCHS'     : None,
    'current_epoch' : None,
    'learning' : None
}

# %% [markdown]
# MAIN

# %%
BATCH_SIZE = 8
RANDOM_SEED = 123
NUM_EPOCHS = 20
last_epoch = 0
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Використовується пристрій: {DEVICE}")
# Out:
# Використовується пристрій: cuda

# %%
directory = '/content/drive/MyDrive'

# Получение списка всех файлов и папок в директории
files_and_folders = os.listdir(directory)

# Отображаем только папки
folders = [f for f in files_and_folders if os.path.isdir(os.path.join(directory, f))]

print(folders)
# Out:
# ['Colab Notebooks', '08', '05', '10', '02', '03', '09', '06', '04', '00', '01', '07', 'checpoint']

# %%
from torch.optim.lr_scheduler import StepLR
set_all_seeds(RANDOM_SEED)

model = Network()
model = model.to(DEVICE)
# optimizer = torch.optim.Adam(model.parameters(), lr = 0.0001, weight_decay = 0.0006)
optimizer = torch.optim.Adam(model.parameters(), lr = 0.0001, weight_decay = 0.0001)
train_loader, validation_loader, test_loader = get_data(batch_size = BATCH_SIZE)
# scheduler = StepLR(optimizer, step_size = 4, gamma = 0.3)
scheduler = None
scaler = GradScaler()
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:01<00:00, 86.9MB/s]
# The model has 6,424,705 trainable parameters
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %%
# Загрузка словаря из файла
path = './5_epoch.pth'
checkpoint = torch.load(path)
if scheduler == None:
    scheduler = StepLR(optimizer, step_size = 1, gamma = 1)
# # Загрузка состояния модели
# save_check = checkpoint['optimizer_state_dict']
# save_check['lr'] = 0.0003
model.load_state_dict( checkpoint['state_model'] )
optimizer.load_state_dict( checkpoint['state_opt'] )
scheduler.load_state_dict( checkpoint['state_scheduler'] )
last_epoch = checkpoint['current_epoch']
# # Загрузка состояния оптимизатора
# optimizer.load_state_dict(save_check)

# %%
if scheduler == None:
    scheduler = StepLR(optimizer, step_size = 1, gamma = 1)
minibatch_loss, train_acc, valid_acc = train(model = model,
            num_epochs = NUM_EPOCHS,
            last_epoch = last_epoch,
            train_loader = train_loader,
            validation_loader = validation_loader,
            test_loader = test_loader,
            optimizer = optimizer,
            device = DEVICE,
            scheduler = scheduler,
            checkpoint_dict = checkpoint_dict,
            scaler = scaler)
# Out:
# Epoch: 001/020 | Batch 0000/2550 | Loss: 0.7133| Learning rate: 0.0001
# Epoch: 001/020 | Batch 0100/2550 | Loss: 0.0538| Learning rate: 0.0001
# Epoch: 001/020 | Batch 0200/2550 | Loss: 0.0943| Learning rate: 0.0001
# Epoch: 001/020 | Batch 0300/2550 | Loss: 0.1539| Learning rate: 0.0001
# Epoch: 001/020 | Batch 0400/2550 | Loss: 0.0348| Learning rate: 0.0001
# Epoch: 001/020 | Batch 0500/2550 | Loss: 0.0425| Learning rate: 0.0001
# Epoch: 001/020 | Batch 0600/2550 | Loss: 0.0649| Learning rate: 0.0001
# Epoch: 001/020 | Batch 0700/2550 | Loss: 0.0228| Learning rate: 0.0001
# Epoch: 001/020 | Batch 0800/2550 | Loss: 0.0685| Learning rate: 0.0001
# Epoch: 001/020 | Batch 0900/2550 | Loss: 0.0234| Learning rate: 0.0001
# Epoch: 001/020 | Batch 1000/2550 | Loss: 0.0232| Learning rate: 0.0001
# Epoch: 001/020 | Batch 1100/2550 | Loss: 0.0729| Learning rate: 0.0001
# Epoch: 001/020 | Batch 1200/2550 | Loss: 0.0278| Learning rate: 0.0001
# Epoch: 001/020 | Batch 1300/2550 | Loss: 0.0367| Learning rate: 0.0001
# Epoch: 001/020 | Batch 1400/2550 | Loss: 0.0309| Learning rate: 0.0001
# Epoch: 001/020 | Batch 1500/2550 | Loss: 0.0102| Learning rate: 0.0001
# Epoch: 001/020 | Batch 1600/2550 | Loss: 0.0089| Learning rate: 0.0001
# Epoch: 001/020 | Batch 1700/2550 | Loss: 0.0188| Learning rate: 0.0001
# Epoch: 001/020 | Batch 1800/2550 | Loss: 0.0189| Learning rate: 0.0001
# Epoch: 001/020 | Batch 1900/2550 | Loss: 0.0180| Learning rate: 0.0001
# Epoch: 001/020 | Batch 2000/2550 | Loss: 0.0142| Learning rate: 0.0001
# Epoch: 001/020 | Batch 2100/2550 | Loss: 0.0268| Learning rate: 0.0001
# Epoch: 001/020 | Batch 2200/2550 | Loss: 0.0369| Learning rate: 0.0001
# Epoch: 001/020 | Batch 2300/2550 | Loss: 0.0099| Learning rate: 0.0001
# Epoch: 001/020 | Batch 2400/2550 | Loss: 0.0176| Learning rate: 0.0001
# Epoch: 001/020 | Batch 2500/2550 | Loss: 0.0322| Learning rate: 0.0001
# Predicted: tensor([[0.4431],
#         [0.9893],
#         [0.7583],
#         [0.8164],
#         [0.3962],
#         [0.1575],
#         [0.7388],
#         [1.3604]], device='cuda:0', dtype=torch.float16)
# , real: tensor([[0.4183],
#         [1.0143],
#         [0.6565],
#         [0.8125],
#         [0.3209],
#         [0.1263],
#         [0.6821],
#         [1.4710]], device='cuda:0')
# Predicted: tensor([[0.7832],
#         [0.8379],
#         [0.7656],
#         [0.7739],
#         [0.7710],
#         [0.7256],
#         [0.7812],
#         [0.9419]], device='cuda:0', dtype=torch.float16)
# , real: tensor([[0.2890],
#         [0.2933],
#         [0.2989],
#         [0.3062],
#         [0.3157],
#         [0.3235],
#         [0.3380],
#         [0.3557]], device='cuda:0')
# Epoch: 001/020 | Train AVG LOSS:  0.0169 | Accuracy_train:  0.5557
# | Validation AVG LOSS:  0.0981 | Accuracy_val:  0.2730
# Time elapsed: 56.20 min
# Epoch: 002/020 | Batch 0000/2550 | Loss: 0.0153| Learning rate: 0.0001
# Epoch: 002/020 | Batch 0100/2550 | Loss: 0.0162| Learning rate: 0.0001
# Epoch: 002/020 | Batch 0200/2550 | Loss: 0.0315| Learning rate: 0.0001
# Epoch: 002/020 | Batch 0300/2550 | Loss: 0.0395| Learning rate: 0.0001
# Epoch: 002/020 | Batch 0400/2550 | Loss: 0.0128| Learning rate: 0.0001
# Epoch: 002/020 | Batch 0500/2550 | Loss: 0.0095| Learning rate: 0.0001
# Epoch: 002/020 | Batch 0600/2550 | Loss: 0.0360| Learning rate: 0.0001
# Epoch: 002/020 | Batch 0700/2550 | Loss: 0.0106| Learning rate: 0.0001
# Epoch: 002/020 | Batch 0800/2550 | Loss: 0.0219| Learning rate: 0.0001
# Epoch: 002/020 | Batch 0900/2550 | Loss: 0.0221| Learning rate: 0.0001
# Epoch: 002/020 | Batch 1000/2550 | Loss: 0.0238| Learning rate: 0.0001
# Epoch: 002/020 | Batch 1100/2550 | Loss: 0.0091| Learning rate: 0.0001
# Epoch: 002/020 | Batch 1200/2550 | Loss: 0.0087| Learning rate: 0.0001
# Epoch: 002/020 | Batch 1300/2550 | Loss: 0.0100| Learning rate: 0.0001
# Epoch: 002/020 | Batch 1400/2550 | Loss: 0.0464| Learning rate: 0.0001
# Epoch: 002/020 | Batch 1500/2550 | Loss: 0.0178| Learning rate: 0.0001
# Epoch: 002/020 | Batch 1600/2550 | Loss: 0.0077| Learning rate: 0.0001
# Epoch: 002/020 | Batch 1700/2550 | Loss: 0.0184| Learning rate: 0.0001
# Epoch: 002/020 | Batch 1800/2550 | Loss: 0.0112| Learning rate: 0.0001
# Epoch: 002/020 | Batch 1900/2550 | Loss: 0.0116| Learning rate: 0.0001
# Epoch: 002/020 | Batch 2000/2550 | Loss: 0.0238| Learning rate: 0.0001
# Epoch: 002/020 | Batch 2100/2550 | Loss: 0.0093| Learning rate: 0.0001
# Epoch: 002/020 | Batch 2200/2550 | Loss: 0.0244| Learning rate: 0.0001
# Epoch: 002/020 | Batch 2300/2550 | Loss: 0.0321| Learning rate: 0.0001
# Epoch: 002/020 | Batch 2400/2550 | Loss: 0.0114| Learning rate: 0.0001
# Epoch: 002/020 | Batch 2500/2550 | Loss: 0.0092| Learning rate: 0.0001
# Predicted: tensor([[0.4514],
#         [0.8066],
#         [0.8311],
#         [0.2312],
#         [1.0215],
#         [1.2295],
#         [1.1895],
#         [0.7944]], device='cuda:0', dtype=torch.float16)
# , real: tensor([[0.3373],
#         [0.8669],
#         [0.7723],
#         [0.3081],
#         [1.2243],
#         [1.1800],
#         [1.1976],
#         [0.6861]], device='cuda:0')
# Predicted: tensor([[0.7832],
#         [0.7324],
#         [0.7139],
#         [0.7349],
#         [0.7129],
#         [0.6621],
#         [0.7339],
#         [0.9312]], device='cuda:0', dtype=torch.float16)
# , real: tensor([[0.2890],
#         [0.2933],
#         [0.2989],
#         [0.3062],
#         [0.3157],
#         [0.3235],
#         [0.3380],
#         [0.3557]], device='cuda:0')
# Epoch: 002/020 | Train AVG LOSS:  0.0106 | Accuracy_train:  0.6720
# | Validation AVG LOSS:  0.0813 | Accuracy_val:  0.2792
# Time elapsed: 75.75 min
# Epoch: 003/020 | Batch 0000/2550 | Loss: 0.0218| Learning rate: 0.0001
# Epoch: 003/020 | Batch 0100/2550 | Loss: 0.0158| Learning rate: 0.0001
# Epoch: 003/020 | Batch 0200/2550 | Loss: 0.0161| Learning rate: 0.0001
# Epoch: 003/020 | Batch 0300/2550 | Loss: 0.0069| Learning rate: 0.0001
# Epoch: 003/020 | Batch 0400/2550 | Loss: 0.0088| Learning rate: 0.0001
# Epoch: 003/020 | Batch 0500/2550 | Loss: 0.0095| Learning rate: 0.0001
# Epoch: 003/020 | Batch 0600/2550 | Loss: 0.0111| Learning rate: 0.0001
# Epoch: 003/020 | Batch 0700/2550 | Loss: 0.0358| Learning rate: 0.0001
# Epoch: 003/020 | Batch 0800/2550 | Loss: 0.0093| Learning rate: 0.0001
# Epoch: 003/020 | Batch 0900/2550 | Loss: 0.0097| Learning rate: 0.0001
# Epoch: 003/020 | Batch 1000/2550 | Loss: 0.0044| Learning rate: 0.0001
# Epoch: 003/020 | Batch 1100/2550 | Loss: 0.0047| Learning rate: 0.0001
# Epoch: 003/020 | Batch 1200/2550 | Loss: 0.0140| Learning rate: 0.0001
# Epoch: 003/020 | Batch 1300/2550 | Loss: 0.0187| Learning rate: 0.0001
# Epoch: 003/020 | Batch 1400/2550 | Loss: 0.0124| Learning rate: 0.0001
# Epoch: 003/020 | Batch 1500/2550 | Loss: 0.0154| Learning rate: 0.0001
# Epoch: 003/020 | Batch 1600/2550 | Loss: 0.0047| Learning rate: 0.0001
# Epoch: 003/020 | Batch 1700/2550 | Loss: 0.0261| Learning rate: 0.0001
# Epoch: 003/020 | Batch 1800/2550 | Loss: 0.0155| Learning rate: 0.0001
# Epoch: 003/020 | Batch 1900/2550 | Loss: 0.0088| Learning rate: 0.0001
# Epoch: 003/020 | Batch 2000/2550 | Loss: 0.0241| Learning rate: 0.0001
# Epoch: 003/020 | Batch 2100/2550 | Loss: 0.0184| Learning rate: 0.0001
# Epoch: 003/020 | Batch 2200/2550 | Loss: 0.0421| Learning rate: 0.0001
# Epoch: 003/020 | Batch 2300/2550 | Loss: 0.0193| Learning rate: 0.0001
# Epoch: 003/020 | Batch 2400/2550 | Loss: 0.0169| Learning rate: 0.0001
# Epoch: 003/020 | Batch 2500/2550 | Loss: 0.0050| Learning rate: 0.0001
# Predicted: tensor([[0.9678],
#         [1.2939],
#         [1.0488],
#         [0.1484],
#         [0.8901],
#         [2.3008],
#         [2.5410],
#         [1.0273]], device='cuda:0', dtype=torch.float16)
# , real: tensor([[0.7955],
#         [1.2164],
#         [1.0791],
#         [0.0436],
#         [0.8013],
#         [2.2414],
#         [2.5994],
#         [0.9116]], device='cuda:0')
# Predicted: tensor([[0.9917],
#         [0.9468],
#         [0.9146],
#         [0.8770],
#         [0.8745],
#         [0.8877],
#         [0.9678],
#         [1.0566]], device='cuda:0', dtype=torch.float16)
# , real: tensor([[0.2890],
#         [0.2933],
#         [0.2989],
#         [0.3062],
#         [0.3157],
#         [0.3235],
#         [0.3380],
#         [0.3557]], device='cuda:0')
# Epoch: 003/020 | Train AVG LOSS:  0.0131 | Accuracy_train:  0.5988
# | Validation AVG LOSS:  0.0637 | Accuracy_val:  0.3164
# Time elapsed: 95.30 min
# Epoch: 004/020 | Batch 0000/2550 | Loss: 0.0183| Learning rate: 0.0001
# Epoch: 004/020 | Batch 0100/2550 | Loss: 0.0059| Learning rate: 0.0001
# Epoch: 004/020 | Batch 0200/2550 | Loss: 0.0093| Learning rate: 0.0001
# Epoch: 004/020 | Batch 0300/2550 | Loss: 0.0068| Learning rate: 0.0001
# Epoch: 004/020 | Batch 0400/2550 | Loss: 0.0117| Learning rate: 0.0001
# Epoch: 004/020 | Batch 0500/2550 | Loss: 0.0058| Learning rate: 0.0001
# Epoch: 004/020 | Batch 0600/2550 | Loss: 0.0225| Learning rate: 0.0001
# Epoch: 004/020 | Batch 0700/2550 | Loss: 0.0057| Learning rate: 0.0001
# Epoch: 004/020 | Batch 0800/2550 | Loss: 0.0054| Learning rate: 0.0001
# Epoch: 004/020 | Batch 0900/2550 | Loss: 0.0088| Learning rate: 0.0001
# Epoch: 004/020 | Batch 1000/2550 | Loss: 0.0169| Learning rate: 0.0001
# Epoch: 004/020 | Batch 1100/2550 | Loss: 0.0054| Learning rate: 0.0001
# Epoch: 004/020 | Batch 1200/2550 | Loss: 0.0200| Learning rate: 0.0001
# Epoch: 004/020 | Batch 1300/2550 | Loss: 0.0253| Learning rate: 0.0001
# Epoch: 004/020 | Batch 1400/2550 | Loss: 0.0123| Learning rate: 0.0001
# Epoch: 004/020 | Batch 1500/2550 | Loss: 0.0164| Learning rate: 0.0001
# Epoch: 004/020 | Batch 1600/2550 | Loss: 0.0128| Learning rate: 0.0001
# Epoch: 004/020 | Batch 1700/2550 | Loss: 0.0105| Learning rate: 0.0001
# Epoch: 004/020 | Batch 1800/2550 | Loss: 0.0118| Learning rate: 0.0001
# Epoch: 004/020 | Batch 1900/2550 | Loss: 0.0158| Learning rate: 0.0001
# Epoch: 004/020 | Batch 2000/2550 | Loss: 0.0110| Learning rate: 0.0001
# Epoch: 004/020 | Batch 2100/2550 | Loss: 0.0182| Learning rate: 0.0001
# Epoch: 004/020 | Batch 2200/2550 | Loss: 0.0095| Learning rate: 0.0001
# Epoch: 004/020 | Batch 2300/2550 | Loss: 0.0094| Learning rate: 0.0001
# Epoch: 004/020 | Batch 2400/2550 | Loss: 0.0082| Learning rate: 0.0001
# Epoch: 004/020 | Batch 2500/2550 | Loss: 0.0064| Learning rate: 0.0001
# Predicted: tensor([[0.6475],
#         [1.0576],
#         [1.0820],
#         [0.7715],
#         [0.6348],
#         [0.8521],
#         [0.4980],
#         [0.9990]], device='cuda:0', dtype=torch.float16)
# , real: tensor([[0.6707],
#         [0.9812],
#         [1.0498],
#         [0.8252],
#         [0.6127],
#         [0.9030],
#         [0.4959],
#         [0.9744]], device='cuda:0')
# Predicted: tensor([[0.8901],
#         [0.8105],
#         [0.8066],
#         [0.8091],
#         [0.8208],
#         [0.7930],
#         [0.8213],
#         [1.0020]], device='cuda:0', dtype=torch.float16)
# , real: tensor([[0.2890],
#         [0.2933],
#         [0.2989],
#         [0.3062],
#         [0.3157],
#         [0.3235],
#         [0.3380],
#         [0.3557]], device='cuda:0')
# Epoch: 004/020 | Train AVG LOSS:  0.0062 | Accuracy_train:  0.8051
# | Validation AVG LOSS:  0.0762 | Accuracy_val:  0.3151
# Time elapsed: 114.83 min
# Epoch: 005/020 | Batch 0000/2550 | Loss: 0.0071| Learning rate: 0.0001
# Epoch: 005/020 | Batch 0100/2550 | Loss: 0.0138| Learning rate: 0.0001
# Epoch: 005/020 | Batch 0200/2550 | Loss: 0.0045| Learning rate: 0.0001
# Epoch: 005/020 | Batch 0300/2550 | Loss: 0.0154| Learning rate: 0.0001
# Epoch: 005/020 | Batch 0400/2550 | Loss: 0.0028| Learning rate: 0.0001
# Epoch: 005/020 | Batch 0500/2550 | Loss: 0.0093| Learning rate: 0.0001
# Epoch: 005/020 | Batch 0600/2550 | Loss: 0.0072| Learning rate: 0.0001
# Epoch: 005/020 | Batch 0700/2550 | Loss: 0.0144| Learning rate: 0.0001
# Epoch: 005/020 | Batch 0800/2550 | Loss: 0.0067| Learning rate: 0.0001
# Epoch: 005/020 | Batch 0900/2550 | Loss: 0.0033| Learning rate: 0.0001
# Epoch: 005/020 | Batch 1000/2550 | Loss: 0.0222| Learning rate: 0.0001
# Epoch: 005/020 | Batch 1100/2550 | Loss: 0.0029| Learning rate: 0.0001
# Epoch: 005/020 | Batch 1200/2550 | Loss: 0.0115| Learning rate: 0.0001
# Epoch: 005/020 | Batch 1300/2550 | Loss: 0.0077| Learning rate: 0.0001
# Epoch: 005/020 | Batch 1400/2550 | Loss: 0.0180| Learning rate: 0.0001
# Epoch: 005/020 | Batch 1500/2550 | Loss: 0.0042| Learning rate: 0.0001
# Epoch: 005/020 | Batch 1600/2550 | Loss: 0.0078| Learning rate: 0.0001
# Epoch: 005/020 | Batch 1700/2550 | Loss: 0.0172| Learning rate: 0.0001
# Epoch: 005/020 | Batch 1800/2550 | Loss: 0.0090| Learning rate: 0.0001
# Epoch: 005/020 | Batch 1900/2550 | Loss: 0.0072| Learning rate: 0.0001
# Epoch: 005/020 | Batch 2000/2550 | Loss: 0.0063| Learning rate: 0.0001
# Epoch: 005/020 | Batch 2100/2550 | Loss: 0.0376| Learning rate: 0.0001
# Epoch: 005/020 | Batch 2200/2550 | Loss: 0.0108| Learning rate: 0.0001
# Epoch: 005/020 | Batch 2300/2550 | Loss: 0.0069| Learning rate: 0.0001
# Epoch: 005/020 | Batch 2400/2550 | Loss: 0.0201| Learning rate: 0.0001
# Epoch: 005/020 | Batch 2500/2550 | Loss: 0.0217| Learning rate: 0.0001
# Predicted: tensor([[0.9561],
#         [0.3452],
#         [0.8462],
#         [0.7944],
#         [0.7148],
#         [1.2930],
#         [1.4971],
#         [0.8462]], device='cuda:0', dtype=torch.float16)
# , real: tensor([[1.0069],
#         [0.2414],
#         [0.7181],
#         [0.7155],
#         [0.7390],
#         [1.3906],
#         [1.4290],
#         [0.8734]], device='cuda:0')
# Predicted: tensor([[0.9263],
#         [0.8081],
#         [0.8252],
#         [0.7935],
#         [0.8301],
#         [0.8145],
#         [0.8662],
#         [0.9688]], device='cuda:0', dtype=torch.float16)
# , real: tensor([[0.2890],
#         [0.2933],
#         [0.2989],
#         [0.3062],
#         [0.3157],
#         [0.3235],
#         [0.3380],
#         [0.3557]], device='cuda:0')
# Epoch: 005/020 | Train AVG LOSS:  0.0058 | Accuracy_train:  0.8220
# | Validation AVG LOSS:  0.0720 | Accuracy_val:  0.3151
# Time elapsed: 134.36 min
# Epoch: 006/020 | Batch 0000/2550 | Loss: 0.0056| Learning rate: 0.0001
# Epoch: 006/020 | Batch 0100/2550 | Loss: 0.0084| Learning rate: 0.0001
# Epoch: 006/020 | Batch 0200/2550 | Loss: 0.0050| Learning rate: 0.0001
# Epoch: 006/020 | Batch 0300/2550 | Loss: 0.0009| Learning rate: 0.0001
# Epoch: 006/020 | Batch 0400/2550 | Loss: 0.0050| Learning rate: 0.0001
# Epoch: 006/020 | Batch 0500/2550 | Loss: 0.0099| Learning rate: 0.0001
# Epoch: 006/020 | Batch 0600/2550 | Loss: 0.0192| Learning rate: 0.0001
# Epoch: 006/020 | Batch 0700/2550 | Loss: 0.0014| Learning rate: 0.0001
# Epoch: 006/020 | Batch 0800/2550 | Loss: 0.0022| Learning rate: 0.0001
# Epoch: 006/020 | Batch 0900/2550 | Loss: 0.0047| Learning rate: 0.0001
# Epoch: 006/020 | Batch 1000/2550 | Loss: 0.0189| Learning rate: 0.0001
# Epoch: 006/020 | Batch 1100/2550 | Loss: 0.0036| Learning rate: 0.0001
# Epoch: 006/020 | Batch 1200/2550 | Loss: 0.0063| Learning rate: 0.0001
# Epoch: 006/020 | Batch 1300/2550 | Loss: 0.0143| Learning rate: 0.0001
# Epoch: 006/020 | Batch 1400/2550 | Loss: 0.0081| Learning rate: 0.0001
# Epoch: 006/020 | Batch 1500/2550 | Loss: 0.0097| Learning rate: 0.0001
# Epoch: 006/020 | Batch 1600/2550 | Loss: 0.0206| Learning rate: 0.0001
# Epoch: 006/020 | Batch 1700/2550 | Loss: 0.0034| Learning rate: 0.0001
# Epoch: 006/020 | Batch 1800/2550 | Loss: 0.0031| Learning rate: 0.0001
# Epoch: 006/020 | Batch 1900/2550 | Loss: 0.0161| Learning rate: 0.0001
# Epoch: 006/020 | Batch 2000/2550 | Loss: 0.0295| Learning rate: 0.0001
# Epoch: 006/020 | Batch 2100/2550 | Loss: 0.0072| Learning rate: 0.0001
# Epoch: 006/020 | Batch 2200/2550 | Loss: 0.0090| Learning rate: 0.0001
# Epoch: 006/020 | Batch 2300/2550 | Loss: 0.0032| Learning rate: 0.0001
# Epoch: 006/020 | Batch 2400/2550 | Loss: 0.0082| Learning rate: 0.0001
# Epoch: 006/020 | Batch 2500/2550 | Loss: 0.0076| Learning rate: 0.0001
# Predicted: tensor([[1.5029],
#         [0.3379],
#         [1.0215],
#         [0.9443],
#         [1.0186],
#         [0.3352],
#         [0.7529],
#         [0.6475]], device='cuda:0', dtype=torch.float16)
# , real: tensor([[1.4418],
#         [0.3736],
#         [1.0173],
#         [1.0813],
#         [0.9278],
#         [0.4286],
#         [0.8096],
#         [0.6540]], device='cuda:0')
# Predicted: tensor([[0.8984],
#         [0.8379],
#         [0.8296],
#         [0.8032],
#         [0.8423],
#         [0.8398],
#         [0.8818],
#         [1.0293]], device='cuda:0', dtype=torch.float16)
# , real: tensor([[0.2890],
#         [0.2933],
#         [0.2989],
#         [0.3062],
#         [0.3157],
#         [0.3235],
#         [0.3380],
#         [0.3557]], device='cuda:0')
# Epoch: 006/020 | Train AVG LOSS:  0.0056 | Accuracy_train:  0.8260
# | Validation AVG LOSS:  0.0719 | Accuracy_val:  0.3245
# Time elapsed: 153.88 min
# Epoch: 007/020 | Batch 0000/2550 | Loss: 0.0099| Learning rate: 0.0001
# Epoch: 007/020 | Batch 0100/2550 | Loss: 0.0039| Learning rate: 0.0001
# Epoch: 007/020 | Batch 0200/2550 | Loss: 0.0050| Learning rate: 0.0001
# Epoch: 007/020 | Batch 0300/2550 | Loss: 0.0055| Learning rate: 0.0001
# Epoch: 007/020 | Batch 0400/2550 | Loss: 0.0081| Learning rate: 0.0001
# Epoch: 007/020 | Batch 0500/2550 | Loss: 0.0060| Learning rate: 0.0001
# Epoch: 007/020 | Batch 0600/2550 | Loss: 0.0026| Learning rate: 0.0001
# Epoch: 007/020 | Batch 0700/2550 | Loss: 0.0103| Learning rate: 0.0001
# Epoch: 007/020 | Batch 0800/2550 | Loss: 0.0039| Learning rate: 0.0001
# Epoch: 007/020 | Batch 0900/2550 | Loss: 0.0047| Learning rate: 0.0001
# Epoch: 007/020 | Batch 1000/2550 | Loss: 0.0267| Learning rate: 0.0001
# Epoch: 007/020 | Batch 1100/2550 | Loss: 0.0014| Learning rate: 0.0001
# Epoch: 007/020 | Batch 1200/2550 | Loss: 0.0013| Learning rate: 0.0001
# Epoch: 007/020 | Batch 1300/2550 | Loss: 0.0141| Learning rate: 0.0001
# Epoch: 007/020 | Batch 1400/2550 | Loss: 0.0042| Learning rate: 0.0001
# Epoch: 007/020 | Batch 1500/2550 | Loss: 0.0069| Learning rate: 0.0001
# Epoch: 007/020 | Batch 1600/2550 | Loss: 0.0067| Learning rate: 0.0001
# Epoch: 007/020 | Batch 1700/2550 | Loss: 0.0082| Learning rate: 0.0001
# Epoch: 007/020 | Batch 1800/2550 | Loss: 0.0048| Learning rate: 0.0001
# Epoch: 007/020 | Batch 1900/2550 | Loss: 0.0032| Learning rate: 0.0001
# Epoch: 007/020 | Batch 2000/2550 | Loss: 0.0168| Learning rate: 0.0001
# Epoch: 007/020 | Batch 2100/2550 | Loss: 0.0039| Learning rate: 0.0001
# Epoch: 007/020 | Batch 2200/2550 | Loss: 0.0055| Learning rate: 0.0001
# Epoch: 007/020 | Batch 2300/2550 | Loss: 0.0060| Learning rate: 0.0001
# Epoch: 007/020 | Batch 2400/2550 | Loss: 0.0101| Learning rate: 0.0001
# Epoch: 007/020 | Batch 2500/2550 | Loss: 0.0075| Learning rate: 0.0001
# Predicted: tensor([[0.2183],
#         [0.6714],
#         [1.1035],
#         [1.0322],
#         [0.2910],
#         [0.3704],
#         [0.8447],
#         [0.9849]], device='cuda:0', dtype=torch.float16)
# , real: tensor([[0.1783],
#         [0.7411],
#         [1.1296],
#         [0.9796],
#         [0.3426],
#         [0.2430],
#         [0.8122],
#         [0.9763]], device='cuda:0')
# Predicted: tensor([[0.7915],
#         [0.7188],
#         [0.6914],
#         [0.6572],
#         [0.7070],
#         [0.7095],
#         [0.7856],
#         [0.9385]], device='cuda:0', dtype=torch.float16)
# , real: tensor([[0.2890],
#         [0.2933],
#         [0.2989],
#         [0.3062],
#         [0.3157],
#         [0.3235],
#         [0.3380],
#         [0.3557]], device='cuda:0')
# Epoch: 007/020 | Train AVG LOSS:  0.0049 | Accuracy_train:  0.8513
# | Validation AVG LOSS:  0.0686 | Accuracy_val:  0.3346
# Time elapsed: 173.42 min
# Epoch: 008/020 | Batch 0000/2550 | Loss: 0.0064| Learning rate: 0.0001
# Epoch: 008/020 | Batch 0100/2550 | Loss: 0.0038| Learning rate: 0.0001
# Epoch: 008/020 | Batch 0200/2550 | Loss: 0.0035| Learning rate: 0.0001
# Epoch: 008/020 | Batch 0300/2550 | Loss: 0.0081| Learning rate: 0.0001
# Epoch: 008/020 | Batch 0400/2550 | Loss: 0.0054| Learning rate: 0.0001
# Epoch: 008/020 | Batch 0500/2550 | Loss: 0.0063| Learning rate: 0.0001
# Epoch: 008/020 | Batch 0600/2550 | Loss: 0.0045| Learning rate: 0.0001
# Epoch: 008/020 | Batch 0700/2550 | Loss: 0.0028| Learning rate: 0.0001
# Epoch: 008/020 | Batch 0800/2550 | Loss: 0.0071| Learning rate: 0.0001
# Epoch: 008/020 | Batch 0900/2550 | Loss: 0.0018| Learning rate: 0.0001
# Epoch: 008/020 | Batch 1000/2550 | Loss: 0.0058| Learning rate: 0.0001
# Epoch: 008/020 | Batch 1100/2550 | Loss: 0.0025| Learning rate: 0.0001
# Epoch: 008/020 | Batch 1200/2550 | Loss: 0.0118| Learning rate: 0.0001
# Epoch: 008/020 | Batch 1300/2550 | Loss: 0.0120| Learning rate: 0.0001
# Epoch: 008/020 | Batch 1400/2550 | Loss: 0.0110| Learning rate: 0.0001
