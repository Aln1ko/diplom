# %% [markdown]
# Відкриття гугл диска

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# !cp '/content/drive/MyDrive/images.zip' '/content/'
# !unzip /content/images.zip -d /content/
# Out:
# Показано результат, скорочений до останніх рядків (5000).
#   inflating: /content/images/08/image_0/001874.png
#   inflating: /content/images/08/image_0/001875.png
#   inflating: /content/images/08/image_0/001876.png
#   inflating: /content/images/08/image_0/001877.png
#   inflating: /content/images/08/image_0/001878.png
#   inflating: /content/images/08/image_0/001879.png
#   inflating: /content/images/08/image_0/001880.png
#   inflating: /content/images/08/image_0/001881.png
#   inflating: /content/images/08/image_0/001882.png
#   inflating: /content/images/08/image_0/001883.png
#   inflating: /content/images/08/image_0/001884.png
#   inflating: /content/images/08/image_0/001885.png
#   inflating: /content/images/08/image_0/001886.png
#   inflating: /content/images/08/image_0/001887.png
#   inflating: /content/images/08/image_0/001888.png
#   inflating: /content/images/08/image_0/001889.png
#   inflating: /content/images/08/image_0/001890.png
#   inflating: /content/images/08/image_0/001891.png
#   inflating: /content/images/08/image_0/001892.png
#   inflating: /content/images/08/image_0/001893.png
#   inflating: /content/images/08/image_0/001894.png
#   inflating: /content/images/08/image_0/001895.png
#   inflating: /content/images/08/image_0/001896.png
#   inflating: /content/images/08/image_0/001897.png
#   inflating: /content/images/08/image_0/001898.png
#   inflating: /content/images/08/image_0/001899.png
#   inflating: /content/images/08/image_0/001900.png
#   inflating: /content/images/08/image_0/001901.png
#   inflating: /content/images/08/image_0/001902.png
#   inflating: /content/images/08/image_0/001903.png
#   inflating: /content/images/08/image_0/001904.png
#   inflating: /content/images/08/image_0/001905.png
#   inflating: /content/images/08/image_0/001906.png
#   inflating: /content/images/08/image_0/001907.png
#   inflating: /content/images/08/image_0/001908.png
#   inflating: /content/images/08/image_0/001909.png
#   inflating: /content/images/08/image_0/001910.png
#   inflating: /content/images/08/image_0/001911.png
#   inflating: /content/images/08/image_0/001912.png
#   inflating: /content/images/08/image_0/001913.png
#   inflating: /content/images/08/image_0/001914.png
#   inflating: /content/images/08/image_0/001915.png
#   inflating: /content/images/08/image_0/001916.png
#   inflating: /content/images/08/image_0/001917.png
#   inflating: /content/images/08/image_0/001918.png
#   inflating: /content/images/08/image_0/001919.png
#   inflating: /content/images/08/image_0/001920.png
#   inflating: /content/images/08/image_0/001921.png
#   inflating: /content/images/08/image_0/001922.png
#   inflating: /content/images/08/image_0/001923.png
#   inflating: /content/images/08/image_0/001924.png
#   inflating: /content/images/08/image_0/001925.png
#   inflating: /content/images/08/image_0/001926.png
#   inflating: /content/images/08/image_0/001927.png
#   inflating: /content/images/08/image_0/001928.png
#   inflating: /content/images/08/image_0/001929.png
#   inflating: /content/images/08/image_0/001930.png
#   inflating: /content/images/08/image_0/001931.png
#   inflating: /content/images/08/image_0/001932.png
#   inflating: /content/images/08/image_0/001933.png
#   inflating: /content/images/08/image_0/001934.png
#   inflating: /content/images/08/image_0/001935.png
#   inflating: /content/images/08/image_0/001936.png
#   inflating: /content/images/08/image_0/001937.png
#   inflating: /content/images/08/image_0/001938.png
#   inflating: /content/images/08/image_0/001939.png
#   inflating: /content/images/08/image_0/001940.png
#   inflating: /content/images/08/image_0/001941.png
#   inflating: /content/images/08/image_0/001942.png
#   inflating: /content/images/08/image_0/001943.png
#   inflating: /content/images/08/image_0/001944.png
#   inflating: /content/images/08/image_0/001945.png
#   inflating: /content/images/08/image_0/001946.png
#   inflating: /content/images/08/image_0/001947.png
#   inflating: /content/images/08/image_0/001948.png
#   inflating: /content/images/08/image_0/001949.png
#   inflating: /content/images/08/image_0/001950.png
#   inflating: /content/images/08/image_0/001951.png
#   inflating: /content/images/08/image_0/001952.png
#   inflating: /content/images/08/image_0/001953.png
#   inflating: /content/images/08/image_0/001954.png
#   inflating: /content/images/08/image_0/001955.png
#   inflating: /content/images/08/image_0/001956.png
#   inflating: /content/images/08/image_0/001957.png
#   inflating: /content/images/08/image_0/001958.png
#   inflating: /content/images/08/image_0/001959.png
#   inflating: /content/images/08/image_0/001960.png
#   inflating: /content/images/08/image_0/001961.png
#   inflating: /content/images/08/image_0/001962.png
#   inflating: /content/images/08/image_0/001963.png
#   inflating: /content/images/08/image_0/001964.png
#   inflating: /content/images/08/image_0/001965.png
#   inflating: /content/images/08/image_0/001966.png
#   inflating: /content/images/08/image_0/001967.png
#   inflating: /content/images/08/image_0/001968.png
#   inflating: /content/images/08/image_0/001969.png
#   inflating: /content/images/08/image_0/001970.png
#   inflating: /content/images/08/image_0/001971.png
#   inflating: /content/images/08/image_0/001972.png
#   inflating: /content/images/08/image_0/001973.png
#   inflating: /content/images/08/image_0/001974.png
#   inflating: /content/images/08/image_0/001975.png
#   inflating: /content/images/08/image_0/001976.png
#   inflating: /content/images/08/image_0/001977.png
#   inflating: /content/images/08/image_0/001978.png
#   inflating: /content/images/08/image_0/001979.png
#   inflating: /content/images/08/image_0/001980.png
#   inflating: /content/images/08/image_0/001981.png
#   inflating: /content/images/08/image_0/001982.png
#   inflating: /content/images/08/image_0/001983.png
#   inflating: /content/images/08/image_0/001984.png
#   inflating: /content/images/08/image_0/001985.png
#   inflating: /content/images/08/image_0/001986.png
#   inflating: /content/images/08/image_0/001987.png
#   inflating: /content/images/08/image_0/001988.png
#   inflating: /content/images/08/image_0/001989.png
#   inflating: /content/images/08/image_0/001990.png
#   inflating: /content/images/08/image_0/001991.png
#   inflating: /content/images/08/image_0/001992.png
#   inflating: /content/images/08/image_0/001993.png
#   inflating: /content/images/08/image_0/001994.png
#   inflating: /content/images/08/image_0/001995.png
#   inflating: /content/images/08/image_0/001996.png
#   inflating: /content/images/08/image_0/001997.png
#   inflating: /content/images/08/image_0/001998.png
#   inflating: /content/images/08/image_0/001999.png
#   inflating: /content/images/08/image_0/002000.png
#   inflating: /content/images/08/image_0/002001.png
#   inflating: /content/images/08/image_0/002002.png
#   inflating: /content/images/08/image_0/002003.png
#   inflating: /content/images/08/image_0/002004.png
#   inflating: /content/images/08/image_0/002005.png
#   inflating: /content/images/08/image_0/002006.png
#   inflating: /content/images/08/image_0/002007.png
#   inflating: /content/images/08/image_0/002008.png
#   inflating: /content/images/08/image_0/002009.png
#   inflating: /content/images/08/image_0/002010.png
#   inflating: /content/images/08/image_0/002011.png
#   inflating: /content/images/08/image_0/002012.png
#   inflating: /content/images/08/image_0/002013.png
#   inflating: /content/images/08/image_0/002014.png
#   inflating: /content/images/08/image_0/002015.png
#   inflating: /content/images/08/image_0/002016.png
#   inflating: /content/images/08/image_0/002017.png
#   inflating: /content/images/08/image_0/002018.png
#   inflating: /content/images/08/image_0/002019.png
#   inflating: /content/images/08/image_0/002020.png
#   inflating: /content/images/08/image_0/002021.png
#   inflating: /content/images/08/image_0/002022.png
#   inflating: /content/images/08/image_0/002023.png
#   inflating: /content/images/08/image_0/002024.png
#   inflating: /content/images/08/image_0/002025.png
#   inflating: /content/images/08/image_0/002026.png
#   inflating: /content/images/08/image_0/002027.png
#   inflating: /content/images/08/image_0/002028.png
#   inflating: /content/images/08/image_0/002029.png
#   inflating: /content/images/08/image_0/002030.png
#   inflating: /content/images/08/image_0/002031.png
#   inflating: /content/images/08/image_0/002032.png
#   inflating: /content/images/08/image_0/002033.png
#   inflating: /content/images/08/image_0/002034.png
#   inflating: /content/images/08/image_0/002035.png
#   inflating: /content/images/08/image_0/002036.png
#   inflating: /content/images/08/image_0/002037.png
#   inflating: /content/images/08/image_0/002038.png
#   inflating: /content/images/08/image_0/002039.png
#   inflating: /content/images/08/image_0/002040.png
#   inflating: /content/images/08/image_0/002041.png
#   inflating: /content/images/08/image_0/002042.png
#   inflating: /content/images/08/image_0/002043.png
#   inflating: /content/images/08/image_0/002044.png
#   inflating: /content/images/08/image_0/002045.png
#   inflating: /content/images/08/image_0/002046.png
#   inflating: /content/images/08/image_0/002047.png
#   inflating: /content/images/08/image_0/002048.png
#   inflating: /content/images/08/image_0/002049.png
#   inflating: /content/images/08/image_0/002050.png
#   inflating: /content/images/08/image_0/002051.png
#   inflating: /content/images/08/image_0/002052.png
#   inflating: /content/images/08/image_0/002053.png
#   inflating: /content/images/08/image_0/002054.png
#   inflating: /content/images/08/image_0/002055.png
#   inflating: /content/images/08/image_0/002056.png
#   inflating: /content/images/08/image_0/002057.png
#   inflating: /content/images/08/image_0/002058.png
#   inflating: /content/images/08/image_0/002059.png
#   inflating: /content/images/08/image_0/002060.png
#   inflating: /content/images/08/image_0/002061.png
#   inflating: /content/images/08/image_0/002062.png
#   inflating: /content/images/08/image_0/002063.png
#   inflating: /content/images/08/image_0/002064.png
#   inflating: /content/images/08/image_0/002065.png
#   inflating: /content/images/08/image_0/002066.png
#   inflating: /content/images/08/image_0/002067.png
#   inflating: /content/images/08/image_0/002068.png
#   inflating: /content/images/08/image_0/002069.png
#   inflating: /content/images/08/image_0/002070.png
#   inflating: /content/images/08/image_0/002071.png
#   inflating: /content/images/08/image_0/002072.png
#   inflating: /content/images/08/image_0/002073.png
#   inflating: /content/images/08/image_0/002074.png
#   inflating: /content/images/08/image_0/002075.png
#   inflating: /content/images/08/image_0/002076.png
#   inflating: /content/images/08/image_0/002077.png
#   inflating: /content/images/08/image_0/002078.png
#   inflating: /content/images/08/image_0/002079.png
#   inflating: /content/images/08/image_0/002080.png
#   inflating: /content/images/08/image_0/002081.png
#   inflating: /content/images/08/image_0/002082.png
#   inflating: /content/images/08/image_0/002083.png
#   inflating: /content/images/08/image_0/002084.png
#   inflating: /content/images/08/image_0/002085.png
#   inflating: /content/images/08/image_0/002086.png
#   inflating: /content/images/08/image_0/002087.png
#   inflating: /content/images/08/image_0/002088.png
#   inflating: /content/images/08/image_0/002089.png
#   inflating: /content/images/08/image_0/002090.png
#   inflating: /content/images/08/image_0/002091.png
#   inflating: /content/images/08/image_0/002092.png
#   inflating: /content/images/08/image_0/002093.png
#   inflating: /content/images/08/image_0/002094.png
#   inflating: /content/images/08/image_0/002095.png
#   inflating: /content/images/08/image_0/002096.png
#   inflating: /content/images/08/image_0/002097.png
#   inflating: /content/images/08/image_0/002098.png
#   inflating: /content/images/08/image_0/002099.png
#   inflating: /content/images/08/image_0/002100.png
#   inflating: /content/images/08/image_0/002101.png
#   inflating: /content/images/08/image_0/002102.png
#   inflating: /content/images/08/image_0/002103.png
#   inflating: /content/images/08/image_0/002104.png
#   inflating: /content/images/08/image_0/002105.png
#   inflating: /content/images/08/image_0/002106.png
#   inflating: /content/images/08/image_0/002107.png
#   inflating: /content/images/08/image_0/002108.png
#   inflating: /content/images/08/image_0/002109.png
#   inflating: /content/images/08/image_0/002110.png
#   inflating: /content/images/08/image_0/002111.png
#   inflating: /content/images/08/image_0/002112.png
#   inflating: /content/images/08/image_0/002113.png
#   inflating: /content/images/08/image_0/002114.png
#   inflating: /content/images/08/image_0/002115.png
#   inflating: /content/images/08/image_0/002116.png
#   inflating: /content/images/08/image_0/002117.png
#   inflating: /content/images/08/image_0/002118.png
#   inflating: /content/images/08/image_0/002119.png
#   inflating: /content/images/08/image_0/002120.png
#   inflating: /content/images/08/image_0/002121.png
#   inflating: /content/images/08/image_0/002122.png
#   inflating: /content/images/08/image_0/002123.png
#   inflating: /content/images/08/image_0/002124.png
#   inflating: /content/images/08/image_0/002125.png
#   inflating: /content/images/08/image_0/002126.png
#   inflating: /content/images/08/image_0/002127.png
#   inflating: /content/images/08/image_0/002128.png
#   inflating: /content/images/08/image_0/002129.png
#   inflating: /content/images/08/image_0/002130.png
#   inflating: /content/images/08/image_0/002131.png
#   inflating: /content/images/08/image_0/002132.png
#   inflating: /content/images/08/image_0/002133.png
#   inflating: /content/images/08/image_0/002134.png
#   inflating: /content/images/08/image_0/002135.png
#   inflating: /content/images/08/image_0/002136.png
#   inflating: /content/images/08/image_0/002137.png
#   inflating: /content/images/08/image_0/002138.png
#   inflating: /content/images/08/image_0/002139.png
#   inflating: /content/images/08/image_0/002140.png
#   inflating: /content/images/08/image_0/002141.png
#   inflating: /content/images/08/image_0/002142.png
#   inflating: /content/images/08/image_0/002143.png
#   inflating: /content/images/08/image_0/002144.png
#   inflating: /content/images/08/image_0/002145.png
#   inflating: /content/images/08/image_0/002146.png
#   inflating: /content/images/08/image_0/002147.png
#   inflating: /content/images/08/image_0/002148.png
#   inflating: /content/images/08/image_0/002149.png
#   inflating: /content/images/08/image_0/002150.png
#   inflating: /content/images/08/image_0/002151.png
#   inflating: /content/images/08/image_0/002152.png
#   inflating: /content/images/08/image_0/002153.png
#   inflating: /content/images/08/image_0/002154.png
#   inflating: /content/images/08/image_0/002155.png
#   inflating: /content/images/08/image_0/002156.png
#   inflating: /content/images/08/image_0/002157.png
#   inflating: /content/images/08/image_0/002158.png
#   inflating: /content/images/08/image_0/002159.png
#   inflating: /content/images/08/image_0/002160.png
#   inflating: /content/images/08/image_0/002161.png
#   inflating: /content/images/08/image_0/002162.png
#   inflating: /content/images/08/image_0/002163.png
#   inflating: /content/images/08/image_0/002164.png
#   inflating: /content/images/08/image_0/002165.png
#   inflating: /content/images/08/image_0/002166.png
#   inflating: /content/images/08/image_0/002167.png
#   inflating: /content/images/08/image_0/002168.png
#   inflating: /content/images/08/image_0/002169.png
#   inflating: /content/images/08/image_0/002170.png
#   inflating: /content/images/08/image_0/002171.png
#   inflating: /content/images/08/image_0/002172.png
#   inflating: /content/images/08/image_0/002173.png
#   inflating: /content/images/08/image_0/002174.png
#   inflating: /content/images/08/image_0/002175.png
#   inflating: /content/images/08/image_0/002176.png
#   inflating: /content/images/08/image_0/002177.png
#   inflating: /content/images/08/image_0/002178.png
#   inflating: /content/images/08/image_0/002179.png
#   inflating: /content/images/08/image_0/002180.png
#   inflating: /content/images/08/image_0/002181.png
#   inflating: /content/images/08/image_0/002182.png
#   inflating: /content/images/08/image_0/002183.png
#   inflating: /content/images/08/image_0/002184.png
#   inflating: /content/images/08/image_0/002185.png
#   inflating: /content/images/08/image_0/002186.png
#   inflating: /content/images/08/image_0/002187.png
#   inflating: /content/images/08/image_0/002188.png
#   inflating: /content/images/08/image_0/002189.png
#   inflating: /content/images/08/image_0/002190.png
#   inflating: /content/images/08/image_0/002191.png
#   inflating: /content/images/08/image_0/002192.png
#   inflating: /content/images/08/image_0/002193.png
#   inflating: /content/images/08/image_0/002194.png
#   inflating: /content/images/08/image_0/002195.png
#   inflating: /content/images/08/image_0/002196.png
#   inflating: /content/images/08/image_0/002197.png
#   inflating: /content/images/08/image_0/002198.png
#   inflating: /content/images/08/image_0/002199.png
#   inflating: /content/images/08/image_0/002200.png
#   inflating: /content/images/08/image_0/002201.png
#   inflating: /content/images/08/image_0/002202.png
#   inflating: /content/images/08/image_0/002203.png
#   inflating: /content/images/08/image_0/002204.png
#   inflating: /content/images/08/image_0/002205.png
#   inflating: /content/images/08/image_0/002206.png
#   inflating: /content/images/08/image_0/002207.png
#   inflating: /content/images/08/image_0/002208.png
#   inflating: /content/images/08/image_0/002209.png
#   inflating: /content/images/08/image_0/002210.png
#   inflating: /content/images/08/image_0/002211.png
#   inflating: /content/images/08/image_0/002212.png
#   inflating: /content/images/08/image_0/002213.png
#   inflating: /content/images/08/image_0/002214.png
#   inflating: /content/images/08/image_0/002215.png
#   inflating: /content/images/08/image_0/002216.png
#   inflating: /content/images/08/image_0/002217.png
#   inflating: /content/images/08/image_0/002218.png
#   inflating: /content/images/08/image_0/002219.png
#   inflating: /content/images/08/image_0/002220.png
#   inflating: /content/images/08/image_0/002221.png
#   inflating: /content/images/08/image_0/002222.png
#   inflating: /content/images/08/image_0/002223.png
#   inflating: /content/images/08/image_0/002224.png
#   inflating: /content/images/08/image_0/002225.png
#   inflating: /content/images/08/image_0/002226.png
#   inflating: /content/images/08/image_0/002227.png
#   inflating: /content/images/08/image_0/002228.png
#   inflating: /content/images/08/image_0/002229.png
#   inflating: /content/images/08/image_0/002230.png
#   inflating: /content/images/08/image_0/002231.png
#   inflating: /content/images/08/image_0/002232.png
#   inflating: /content/images/08/image_0/002233.png
#   inflating: /content/images/08/image_0/002234.png
#   inflating: /content/images/08/image_0/002235.png
#   inflating: /content/images/08/image_0/002236.png
#   inflating: /content/images/08/image_0/002237.png
#   inflating: /content/images/08/image_0/002238.png
#   inflating: /content/images/08/image_0/002239.png
#   inflating: /content/images/08/image_0/002240.png
#   inflating: /content/images/08/image_0/002241.png
#   inflating: /content/images/08/image_0/002242.png
#   inflating: /content/images/08/image_0/002243.png
#   inflating: /content/images/08/image_0/002244.png
#   inflating: /content/images/08/image_0/002245.png
#   inflating: /content/images/08/image_0/002246.png
#   inflating: /content/images/08/image_0/002247.png
#   inflating: /content/images/08/image_0/002248.png
#   inflating: /content/images/08/image_0/002249.png
#   inflating: /content/images/08/image_0/002250.png
#   inflating: /content/images/08/image_0/002251.png
#   inflating: /content/images/08/image_0/002252.png
#   inflating: /content/images/08/image_0/002253.png
#   inflating: /content/images/08/image_0/002254.png
#   inflating: /content/images/08/image_0/002255.png
#   inflating: /content/images/08/image_0/002256.png
#   inflating: /content/images/08/image_0/002257.png
#   inflating: /content/images/08/image_0/002258.png
#   inflating: /content/images/08/image_0/002259.png
#   inflating: /content/images/08/image_0/002260.png
#   inflating: /content/images/08/image_0/002261.png
#   inflating: /content/images/08/image_0/002262.png
#   inflating: /content/images/08/image_0/002263.png
#   inflating: /content/images/08/image_0/002264.png
#   inflating: /content/images/08/image_0/002265.png
#   inflating: /content/images/08/image_0/002266.png
#   inflating: /content/images/08/image_0/002267.png
#   inflating: /content/images/08/image_0/002268.png
#   inflating: /content/images/08/image_0/002269.png
#   inflating: /content/images/08/image_0/002270.png
#   inflating: /content/images/08/image_0/002271.png
#   inflating: /content/images/08/image_0/002272.png
#   inflating: /content/images/08/image_0/002273.png
#   inflating: /content/images/08/image_0/002274.png
#   inflating: /content/images/08/image_0/002275.png
#   inflating: /content/images/08/image_0/002276.png
#   inflating: /content/images/08/image_0/002277.png
#   inflating: /content/images/08/image_0/002278.png
#   inflating: /content/images/08/image_0/002279.png
#   inflating: /content/images/08/image_0/002280.png
#   inflating: /content/images/08/image_0/002281.png
#   inflating: /content/images/08/image_0/002282.png
#   inflating: /content/images/08/image_0/002283.png
#   inflating: /content/images/08/image_0/002284.png
#   inflating: /content/images/08/image_0/002285.png
#   inflating: /content/images/08/image_0/002286.png
#   inflating: /content/images/08/image_0/002287.png
#   inflating: /content/images/08/image_0/002288.png
#   inflating: /content/images/08/image_0/002289.png
#   inflating: /content/images/08/image_0/002290.png
#   inflating: /content/images/08/image_0/002291.png
#   inflating: /content/images/08/image_0/002292.png
#   inflating: /content/images/08/image_0/002293.png
#   inflating: /content/images/08/image_0/002294.png
#   inflating: /content/images/08/image_0/002295.png
#   inflating: /content/images/08/image_0/002296.png
#   inflating: /content/images/08/image_0/002297.png
#   inflating: /content/images/08/image_0/002298.png
#   inflating: /content/images/08/image_0/002299.png
#   inflating: /content/images/08/image_0/002300.png
#   inflating: /content/images/08/image_0/002301.png
#   inflating: /content/images/08/image_0/002302.png
#   inflating: /content/images/08/image_0/002303.png
#   inflating: /content/images/08/image_0/002304.png
#   inflating: /content/images/08/image_0/002305.png
#   inflating: /content/images/08/image_0/002306.png
#   inflating: /content/images/08/image_0/002307.png
#   inflating: /content/images/08/image_0/002308.png
#   inflating: /content/images/08/image_0/002309.png
#   inflating: /content/images/08/image_0/002310.png
#   inflating: /content/images/08/image_0/002311.png
#   inflating: /content/images/08/image_0/002312.png
#   inflating: /content/images/08/image_0/002313.png
#   inflating: /content/images/08/image_0/002314.png
#   inflating: /content/images/08/image_0/002315.png
#   inflating: /content/images/08/image_0/002316.png
#   inflating: /content/images/08/image_0/002317.png
#   inflating: /content/images/08/image_0/002318.png
#   inflating: /content/images/08/image_0/002319.png
#   inflating: /content/images/08/image_0/002320.png
#   inflating: /content/images/08/image_0/002321.png
#   inflating: /content/images/08/image_0/002322.png
#   inflating: /content/images/08/image_0/002323.png
#   inflating: /content/images/08/image_0/002324.png
#   inflating: /content/images/08/image_0/002325.png
#   inflating: /content/images/08/image_0/002326.png
#   inflating: /content/images/08/image_0/002327.png
#   inflating: /content/images/08/image_0/002328.png
#   inflating: /content/images/08/image_0/002329.png
#   inflating: /content/images/08/image_0/002330.png
#   inflating: /content/images/08/image_0/002331.png
#   inflating: /content/images/08/image_0/002332.png
#   inflating: /content/images/08/image_0/002333.png
#   inflating: /content/images/08/image_0/002334.png
#   inflating: /content/images/08/image_0/002335.png
#   inflating: /content/images/08/image_0/002336.png
#   inflating: /content/images/08/image_0/002337.png
#   inflating: /content/images/08/image_0/002338.png
#   inflating: /content/images/08/image_0/002339.png
#   inflating: /content/images/08/image_0/002340.png
#   inflating: /content/images/08/image_0/002341.png
#   inflating: /content/images/08/image_0/002342.png
#   inflating: /content/images/08/image_0/002343.png
#   inflating: /content/images/08/image_0/002344.png
#   inflating: /content/images/08/image_0/002345.png
#   inflating: /content/images/08/image_0/002346.png
#   inflating: /content/images/08/image_0/002347.png
#   inflating: /content/images/08/image_0/002348.png
#   inflating: /content/images/08/image_0/002349.png
#   inflating: /content/images/08/image_0/002350.png
#   inflating: /content/images/08/image_0/002351.png
#   inflating: /content/images/08/image_0/002352.png
#   inflating: /content/images/08/image_0/002353.png
#   inflating: /content/images/08/image_0/002354.png
#   inflating: /content/images/08/image_0/002355.png
#   inflating: /content/images/08/image_0/002356.png
#   inflating: /content/images/08/image_0/002357.png
#   inflating: /content/images/08/image_0/002358.png
#   inflating: /content/images/08/image_0/002359.png
#   inflating: /content/images/08/image_0/002360.png
#   inflating: /content/images/08/image_0/002361.png
#   inflating: /content/images/08/image_0/002362.png
#   inflating: /content/images/08/image_0/002363.png
#   inflating: /content/images/08/image_0/002364.png
#   inflating: /content/images/08/image_0/002365.png
#   inflating: /content/images/08/image_0/002366.png
#   inflating: /content/images/08/image_0/002367.png
#   inflating: /content/images/08/image_0/002368.png
#   inflating: /content/images/08/image_0/002369.png
#   inflating: /content/images/08/image_0/002370.png
#   inflating: /content/images/08/image_0/002371.png
#   inflating: /content/images/08/image_0/002372.png
#   inflating: /content/images/08/image_0/002373.png
#   inflating: /content/images/08/image_0/002374.png
#   inflating: /content/images/08/image_0/002375.png
#   inflating: /content/images/08/image_0/002376.png
#   inflating: /content/images/08/image_0/002377.png
#   inflating: /content/images/08/image_0/002378.png
#   inflating: /content/images/08/image_0/002379.png
#   inflating: /content/images/08/image_0/002380.png
#   inflating: /content/images/08/image_0/002381.png
#   inflating: /content/images/08/image_0/002382.png
#   inflating: /content/images/08/image_0/002383.png
#   inflating: /content/images/08/image_0/002384.png
#   inflating: /content/images/08/image_0/002385.png
#   inflating: /content/images/08/image_0/002386.png
#   inflating: /content/images/08/image_0/002387.png
#   inflating: /content/images/08/image_0/002388.png
#   inflating: /content/images/08/image_0/002389.png
#   inflating: /content/images/08/image_0/002390.png
#   inflating: /content/images/08/image_0/002391.png
#   inflating: /content/images/08/image_0/002392.png
#   inflating: /content/images/08/image_0/002393.png
#   inflating: /content/images/08/image_0/002394.png
#   inflating: /content/images/08/image_0/002395.png
#   inflating: /content/images/08/image_0/002396.png
#   inflating: /content/images/08/image_0/002397.png
#   inflating: /content/images/08/image_0/002398.png
#   inflating: /content/images/08/image_0/002399.png
#   inflating: /content/images/08/image_0/002400.png
#   inflating: /content/images/08/image_0/002401.png
#   inflating: /content/images/08/image_0/002402.png
#   inflating: /content/images/08/image_0/002403.png
#   inflating: /content/images/08/image_0/002404.png
#   inflating: /content/images/08/image_0/002405.png
#   inflating: /content/images/08/image_0/002406.png
#   inflating: /content/images/08/image_0/002407.png
#   inflating: /content/images/08/image_0/002408.png
#   inflating: /content/images/08/image_0/002409.png
#   inflating: /content/images/08/image_0/002410.png
#   inflating: /content/images/08/image_0/002411.png
#   inflating: /content/images/08/image_0/002412.png
#   inflating: /content/images/08/image_0/002413.png
#   inflating: /content/images/08/image_0/002414.png
#   inflating: /content/images/08/image_0/002415.png
#   inflating: /content/images/08/image_0/002416.png
#   inflating: /content/images/08/image_0/002417.png
#   inflating: /content/images/08/image_0/002418.png
#   inflating: /content/images/08/image_0/002419.png
#   inflating: /content/images/08/image_0/002420.png
#   inflating: /content/images/08/image_0/002421.png
#   inflating: /content/images/08/image_0/002422.png
#   inflating: /content/images/08/image_0/002423.png
#   inflating: /content/images/08/image_0/002424.png
#   inflating: /content/images/08/image_0/002425.png
#   inflating: /content/images/08/image_0/002426.png
#   inflating: /content/images/08/image_0/002427.png
#   inflating: /content/images/08/image_0/002428.png
#   inflating: /content/images/08/image_0/002429.png
#   inflating: /content/images/08/image_0/002430.png
#   inflating: /content/images/08/image_0/002431.png
#   inflating: /content/images/08/image_0/002432.png
#   inflating: /content/images/08/image_0/002433.png
#   inflating: /content/images/08/image_0/002434.png
#   inflating: /content/images/08/image_0/002435.png
#   inflating: /content/images/08/image_0/002436.png
#   inflating: /content/images/08/image_0/002437.png
#   inflating: /content/images/08/image_0/002438.png
#   inflating: /content/images/08/image_0/002439.png
#   inflating: /content/images/08/image_0/002440.png
#   inflating: /content/images/08/image_0/002441.png
#   inflating: /content/images/08/image_0/002442.png
#   inflating: /content/images/08/image_0/002443.png
#   inflating: /content/images/08/image_0/002444.png
#   inflating: /content/images/08/image_0/002445.png
#   inflating: /content/images/08/image_0/002446.png
#   inflating: /content/images/08/image_0/002447.png
#   inflating: /content/images/08/image_0/002448.png
#   inflating: /content/images/08/image_0/002449.png
#   inflating: /content/images/08/image_0/002450.png
#   inflating: /content/images/08/image_0/002451.png
#   inflating: /content/images/08/image_0/002452.png
#   inflating: /content/images/08/image_0/002453.png
#   inflating: /content/images/08/image_0/002454.png
#   inflating: /content/images/08/image_0/002455.png
#   inflating: /content/images/08/image_0/002456.png
#   inflating: /content/images/08/image_0/002457.png
#   inflating: /content/images/08/image_0/002458.png
#   inflating: /content/images/08/image_0/002459.png
#   inflating: /content/images/08/image_0/002460.png
#   inflating: /content/images/08/image_0/002461.png
#   inflating: /content/images/08/image_0/002462.png
#   inflating: /content/images/08/image_0/002463.png
#   inflating: /content/images/08/image_0/002464.png
#   inflating: /content/images/08/image_0/002465.png
#   inflating: /content/images/08/image_0/002466.png
#   inflating: /content/images/08/image_0/002467.png
#   inflating: /content/images/08/image_0/002468.png
#   inflating: /content/images/08/image_0/002469.png
#   inflating: /content/images/08/image_0/002470.png
#   inflating: /content/images/08/image_0/002471.png
#   inflating: /content/images/08/image_0/002472.png
#   inflating: /content/images/08/image_0/002473.png
#   inflating: /content/images/08/image_0/002474.png
#   inflating: /content/images/08/image_0/002475.png
#   inflating: /content/images/08/image_0/002476.png
#   inflating: /content/images/08/image_0/002477.png
#   inflating: /content/images/08/image_0/002478.png
#   inflating: /content/images/08/image_0/002479.png
#   inflating: /content/images/08/image_0/002480.png
#   inflating: /content/images/08/image_0/002481.png
#   inflating: /content/images/08/image_0/002482.png
#   inflating: /content/images/08/image_0/002483.png
#   inflating: /content/images/08/image_0/002484.png
#   inflating: /content/images/08/image_0/002485.png
#   inflating: /content/images/08/image_0/002486.png
#   inflating: /content/images/08/image_0/002487.png
#   inflating: /content/images/08/image_0/002488.png
#   inflating: /content/images/08/image_0/002489.png
#   inflating: /content/images/08/image_0/002490.png
#   inflating: /content/images/08/image_0/002491.png
#   inflating: /content/images/08/image_0/002492.png
#   inflating: /content/images/08/image_0/002493.png
#   inflating: /content/images/08/image_0/002494.png
#   inflating: /content/images/08/image_0/002495.png
#   inflating: /content/images/08/image_0/002496.png
#   inflating: /content/images/08/image_0/002497.png
#   inflating: /content/images/08/image_0/002498.png
#   inflating: /content/images/08/image_0/002499.png
#   inflating: /content/images/08/image_0/002500.png
#   inflating: /content/images/08/image_0/002501.png
#   inflating: /content/images/08/image_0/002502.png
#   inflating: /content/images/08/image_0/002503.png
#   inflating: /content/images/08/image_0/002504.png
#   inflating: /content/images/08/image_0/002505.png
#   inflating: /content/images/08/image_0/002506.png
#   inflating: /content/images/08/image_0/002507.png
#   inflating: /content/images/08/image_0/002508.png
#   inflating: /content/images/08/image_0/002509.png
#   inflating: /content/images/08/image_0/002510.png
#   inflating: /content/images/08/image_0/002511.png
#   inflating: /content/images/08/image_0/002512.png
#   inflating: /content/images/08/image_0/002513.png
#   inflating: /content/images/08/image_0/002514.png
#   inflating: /content/images/08/image_0/002515.png
#   inflating: /content/images/08/image_0/002516.png
#   inflating: /content/images/08/image_0/002517.png
#   inflating: /content/images/08/image_0/002518.png
#   inflating: /content/images/08/image_0/002519.png
#   inflating: /content/images/08/image_0/002520.png
#   inflating: /content/images/08/image_0/002521.png
#   inflating: /content/images/08/image_0/002522.png
#   inflating: /content/images/08/image_0/002523.png
#   inflating: /content/images/08/image_0/002524.png
#   inflating: /content/images/08/image_0/002525.png
#   inflating: /content/images/08/image_0/002526.png
#   inflating: /content/images/08/image_0/002527.png
#   inflating: /content/images/08/image_0/002528.png
#   inflating: /content/images/08/image_0/002529.png
#   inflating: /content/images/08/image_0/002530.png
#   inflating: /content/images/08/image_0/002531.png
#   inflating: /content/images/08/image_0/002532.png
#   inflating: /content/images/08/image_0/002533.png
#   inflating: /content/images/08/image_0/002534.png
#   inflating: /content/images/08/image_0/002535.png
#   inflating: /content/images/08/image_0/002536.png
#   inflating: /content/images/08/image_0/002537.png
#   inflating: /content/images/08/image_0/002538.png
#   inflating: /content/images/08/image_0/002539.png
#   inflating: /content/images/08/image_0/002540.png
#   inflating: /content/images/08/image_0/002541.png
#   inflating: /content/images/08/image_0/002542.png
#   inflating: /content/images/08/image_0/002543.png
#   inflating: /content/images/08/image_0/002544.png
#   inflating: /content/images/08/image_0/002545.png
#   inflating: /content/images/08/image_0/002546.png
#   inflating: /content/images/08/image_0/002547.png
#   inflating: /content/images/08/image_0/002548.png
#   inflating: /content/images/08/image_0/002549.png
#   inflating: /content/images/08/image_0/002550.png
#   inflating: /content/images/08/image_0/002551.png
#   inflating: /content/images/08/image_0/002552.png
#   inflating: /content/images/08/image_0/002553.png
#   inflating: /content/images/08/image_0/002554.png
#   inflating: /content/images/08/image_0/002555.png
#   inflating: /content/images/08/image_0/002556.png
#   inflating: /content/images/08/image_0/002557.png
#   inflating: /content/images/08/image_0/002558.png
#   inflating: /content/images/08/image_0/002559.png
#   inflating: /content/images/08/image_0/002560.png
#   inflating: /content/images/08/image_0/002561.png
#   inflating: /content/images/08/image_0/002562.png
#   inflating: /content/images/08/image_0/002563.png
#   inflating: /content/images/08/image_0/002564.png
#   inflating: /content/images/08/image_0/002565.png
#   inflating: /content/images/08/image_0/002566.png
#   inflating: /content/images/08/image_0/002567.png
#   inflating: /content/images/08/image_0/002568.png
#   inflating: /content/images/08/image_0/002569.png
#   inflating: /content/images/08/image_0/002570.png
#   inflating: /content/images/08/image_0/002571.png
#   inflating: /content/images/08/image_0/002572.png
#   inflating: /content/images/08/image_0/002573.png
#   inflating: /content/images/08/image_0/002574.png
#   inflating: /content/images/08/image_0/002575.png
#   inflating: /content/images/08/image_0/002576.png
#   inflating: /content/images/08/image_0/002577.png
#   inflating: /content/images/08/image_0/002578.png
#   inflating: /content/images/08/image_0/002579.png
#   inflating: /content/images/08/image_0/002580.png
#   inflating: /content/images/08/image_0/002581.png
#   inflating: /content/images/08/image_0/002582.png
#   inflating: /content/images/08/image_0/002583.png
#   inflating: /content/images/08/image_0/002584.png
#   inflating: /content/images/08/image_0/002585.png
#   inflating: /content/images/08/image_0/002586.png
#   inflating: /content/images/08/image_0/002587.png
#   inflating: /content/images/08/image_0/002588.png
#   inflating: /content/images/08/image_0/002589.png
#   inflating: /content/images/08/image_0/002590.png
#   inflating: /content/images/08/image_0/002591.png
#   inflating: /content/images/08/image_0/002592.png
#   inflating: /content/images/08/image_0/002593.png
#   inflating: /content/images/08/image_0/002594.png
#   inflating: /content/images/08/image_0/002595.png
#   inflating: /content/images/08/image_0/002596.png
#   inflating: /content/images/08/image_0/002597.png
#   inflating: /content/images/08/image_0/002598.png
#   inflating: /content/images/08/image_0/002599.png
#   inflating: /content/images/08/image_0/002600.png
#   inflating: /content/images/08/image_0/002601.png
#   inflating: /content/images/08/image_0/002602.png
#   inflating: /content/images/08/image_0/002603.png
#   inflating: /content/images/08/image_0/002604.png
#   inflating: /content/images/08/image_0/002605.png
#   inflating: /content/images/08/image_0/002606.png
#   inflating: /content/images/08/image_0/002607.png
#   inflating: /content/images/08/image_0/002608.png
#   inflating: /content/images/08/image_0/002609.png
#   inflating: /content/images/08/image_0/002610.png
#   inflating: /content/images/08/image_0/002611.png
#   inflating: /content/images/08/image_0/002612.png
#   inflating: /content/images/08/image_0/002613.png
#   inflating: /content/images/08/image_0/002614.png
#   inflating: /content/images/08/image_0/002615.png
#   inflating: /content/images/08/image_0/002616.png
#   inflating: /content/images/08/image_0/002617.png
#   inflating: /content/images/08/image_0/002618.png
#   inflating: /content/images/08/image_0/002619.png
#   inflating: /content/images/08/image_0/002620.png
#   inflating: /content/images/08/image_0/002621.png
#   inflating: /content/images/08/image_0/002622.png
#   inflating: /content/images/08/image_0/002623.png
#   inflating: /content/images/08/image_0/002624.png
#   inflating: /content/images/08/image_0/002625.png
#   inflating: /content/images/08/image_0/002626.png
#   inflating: /content/images/08/image_0/002627.png
#   inflating: /content/images/08/image_0/002628.png
#   inflating: /content/images/08/image_0/002629.png
#   inflating: /content/images/08/image_0/002630.png
#   inflating: /content/images/08/image_0/002631.png
#   inflating: /content/images/08/image_0/002632.png
#   inflating: /content/images/08/image_0/002633.png
#   inflating: /content/images/08/image_0/002634.png
#   inflating: /content/images/08/image_0/002635.png
#   inflating: /content/images/08/image_0/002636.png
#   inflating: /content/images/08/image_0/002637.png
#   inflating: /content/images/08/image_0/002638.png
#   inflating: /content/images/08/image_0/002639.png
#   inflating: /content/images/08/image_0/002640.png
#   inflating: /content/images/08/image_0/002641.png
#   inflating: /content/images/08/image_0/002642.png
#   inflating: /content/images/08/image_0/002643.png
#   inflating: /content/images/08/image_0/002644.png
#   inflating: /content/images/08/image_0/002645.png
#   inflating: /content/images/08/image_0/002646.png
#   inflating: /content/images/08/image_0/002647.png
#   inflating: /content/images/08/image_0/002648.png
#   inflating: /content/images/08/image_0/002649.png
#   inflating: /content/images/08/image_0/002650.png
#   inflating: /content/images/08/image_0/002651.png
#   inflating: /content/images/08/image_0/002652.png
#   inflating: /content/images/08/image_0/002653.png
#   inflating: /content/images/08/image_0/002654.png
#   inflating: /content/images/08/image_0/002655.png
#   inflating: /content/images/08/image_0/002656.png
#   inflating: /content/images/08/image_0/002657.png
#   inflating: /content/images/08/image_0/002658.png
#   inflating: /content/images/08/image_0/002659.png
#   inflating: /content/images/08/image_0/002660.png
#   inflating: /content/images/08/image_0/002661.png
#   inflating: /content/images/08/image_0/002662.png
#   inflating: /content/images/08/image_0/002663.png
#   inflating: /content/images/08/image_0/002664.png
#   inflating: /content/images/08/image_0/002665.png
#   inflating: /content/images/08/image_0/002666.png
#   inflating: /content/images/08/image_0/002667.png
#   inflating: /content/images/08/image_0/002668.png
#   inflating: /content/images/08/image_0/002669.png
#   inflating: /content/images/08/image_0/002670.png
#   inflating: /content/images/08/image_0/002671.png
#   inflating: /content/images/08/image_0/002672.png
#   inflating: /content/images/08/image_0/002673.png
#   inflating: /content/images/08/image_0/002674.png
#   inflating: /content/images/08/image_0/002675.png
#   inflating: /content/images/08/image_0/002676.png
#   inflating: /content/images/08/image_0/002677.png
#   inflating: /content/images/08/image_0/002678.png
#   inflating: /content/images/08/image_0/002679.png
#   inflating: /content/images/08/image_0/002680.png
#   inflating: /content/images/08/image_0/002681.png
#   inflating: /content/images/08/image_0/002682.png
#   inflating: /content/images/08/image_0/002683.png
#   inflating: /content/images/08/image_0/002684.png
#   inflating: /content/images/08/image_0/002685.png
#   inflating: /content/images/08/image_0/002686.png
#   inflating: /content/images/08/image_0/002687.png
#   inflating: /content/images/08/image_0/002688.png
#   inflating: /content/images/08/image_0/002689.png
#   inflating: /content/images/08/image_0/002690.png
#   inflating: /content/images/08/image_0/002691.png
#   inflating: /content/images/08/image_0/002692.png
#   inflating: /content/images/08/image_0/002693.png
#   inflating: /content/images/08/image_0/002694.png
#   inflating: /content/images/08/image_0/002695.png
#   inflating: /content/images/08/image_0/002696.png
#   inflating: /content/images/08/image_0/002697.png
#   inflating: /content/images/08/image_0/002698.png
#   inflating: /content/images/08/image_0/002699.png
#   inflating: /content/images/08/image_0/002700.png
#   inflating: /content/images/08/image_0/002701.png
#   inflating: /content/images/08/image_0/002702.png
#   inflating: /content/images/08/image_0/002703.png
#   inflating: /content/images/08/image_0/002704.png
#   inflating: /content/images/08/image_0/002705.png
#   inflating: /content/images/08/image_0/002706.png
#   inflating: /content/images/08/image_0/002707.png
#   inflating: /content/images/08/image_0/002708.png
#   inflating: /content/images/08/image_0/002709.png
#   inflating: /content/images/08/image_0/002710.png
#   inflating: /content/images/08/image_0/002711.png
#   inflating: /content/images/08/image_0/002712.png
#   inflating: /content/images/08/image_0/002713.png
#   inflating: /content/images/08/image_0/002714.png
#   inflating: /content/images/08/image_0/002715.png
#   inflating: /content/images/08/image_0/002716.png
#   inflating: /content/images/08/image_0/002717.png
#   inflating: /content/images/08/image_0/002718.png
#   inflating: /content/images/08/image_0/002719.png
#   inflating: /content/images/08/image_0/002720.png
#   inflating: /content/images/08/image_0/002721.png
#   inflating: /content/images/08/image_0/002722.png
#   inflating: /content/images/08/image_0/002723.png
#   inflating: /content/images/08/image_0/002724.png
#   inflating: /content/images/08/image_0/002725.png
#   inflating: /content/images/08/image_0/002726.png
#   inflating: /content/images/08/image_0/002727.png
#   inflating: /content/images/08/image_0/002728.png
#   inflating: /content/images/08/image_0/002729.png
#   inflating: /content/images/08/image_0/002730.png
#   inflating: /content/images/08/image_0/002731.png
#   inflating: /content/images/08/image_0/002732.png
#   inflating: /content/images/08/image_0/002733.png
#   inflating: /content/images/08/image_0/002734.png
#   inflating: /content/images/08/image_0/002735.png
#   inflating: /content/images/08/image_0/002736.png
#   inflating: /content/images/08/image_0/002737.png
#   inflating: /content/images/08/image_0/002738.png
#   inflating: /content/images/08/image_0/002739.png
#   inflating: /content/images/08/image_0/002740.png
#   inflating: /content/images/08/image_0/002741.png
#   inflating: /content/images/08/image_0/002742.png
#   inflating: /content/images/08/image_0/002743.png
#   inflating: /content/images/08/image_0/002744.png
#   inflating: /content/images/08/image_0/002745.png
#   inflating: /content/images/08/image_0/002746.png
#   inflating: /content/images/08/image_0/002747.png
#   inflating: /content/images/08/image_0/002748.png
#   inflating: /content/images/08/image_0/002749.png
#   inflating: /content/images/08/image_0/002750.png
#   inflating: /content/images/08/image_0/002751.png
#   inflating: /content/images/08/image_0/002752.png
#   inflating: /content/images/08/image_0/002753.png
#   inflating: /content/images/08/image_0/002754.png
#   inflating: /content/images/08/image_0/002755.png
#   inflating: /content/images/08/image_0/002756.png
#   inflating: /content/images/08/image_0/002757.png
#   inflating: /content/images/08/image_0/002758.png
#   inflating: /content/images/08/image_0/002759.png
#   inflating: /content/images/08/image_0/002760.png
#   inflating: /content/images/08/image_0/002761.png
#   inflating: /content/images/08/image_0/002762.png
#   inflating: /content/images/08/image_0/002763.png
#   inflating: /content/images/08/image_0/002764.png
#   inflating: /content/images/08/image_0/002765.png
#   inflating: /content/images/08/image_0/002766.png
#   inflating: /content/images/08/image_0/002767.png
#   inflating: /content/images/08/image_0/002768.png
#   inflating: /content/images/08/image_0/002769.png
#   inflating: /content/images/08/image_0/002770.png
#   inflating: /content/images/08/image_0/002771.png
#   inflating: /content/images/08/image_0/002772.png
#   inflating: /content/images/08/image_0/002773.png
#   inflating: /content/images/08/image_0/002774.png
#   inflating: /content/images/08/image_0/002775.png
#   inflating: /content/images/08/image_0/002776.png
#   inflating: /content/images/08/image_0/002777.png
# ...
#   inflating: /content/images/10/image_0/000900.png
#   inflating: /content/images/10/image_0/000901.png
#   inflating: /content/images/10/image_0/000902.png
#   inflating: /content/images/10/image_0/000903.png
#   inflating: /content/images/10/image_0/000904.png
#   inflating: /content/images/10/image_0/000905.png
#   inflating: /content/images/10/image_0/000906.png
#   inflating: /content/images/10/image_0/000907.png
#   inflating: /content/images/10/image_0/000908.png
#   inflating: /content/images/10/image_0/000909.png
#   inflating: /content/images/10/image_0/000910.png
#   inflating: /content/images/10/image_0/000911.png
#   inflating: /content/images/10/image_0/000912.png
#   inflating: /content/images/10/image_0/000913.png
#   inflating: /content/images/10/image_0/000914.png
#   inflating: /content/images/10/image_0/000915.png
#   inflating: /content/images/10/image_0/000916.png
#   inflating: /content/images/10/image_0/000917.png
#   inflating: /content/images/10/image_0/000918.png
#   inflating: /content/images/10/image_0/000919.png
#   inflating: /content/images/10/image_0/000920.png
#   inflating: /content/images/10/image_0/000921.png
#   inflating: /content/images/10/image_0/000922.png
#   inflating: /content/images/10/image_0/000923.png
#   inflating: /content/images/10/image_0/000924.png
#   inflating: /content/images/10/image_0/000925.png
#   inflating: /content/images/10/image_0/000926.png
#   inflating: /content/images/10/image_0/000927.png
#   inflating: /content/images/10/image_0/000928.png
#   inflating: /content/images/10/image_0/000929.png
#   inflating: /content/images/10/image_0/000930.png
#   inflating: /content/images/10/image_0/000931.png
#   inflating: /content/images/10/image_0/000932.png
#   inflating: /content/images/10/image_0/000933.png
#   inflating: /content/images/10/image_0/000934.png
#   inflating: /content/images/10/image_0/000935.png
#   inflating: /content/images/10/image_0/000936.png
#   inflating: /content/images/10/image_0/000937.png
#   inflating: /content/images/10/image_0/000938.png
#   inflating: /content/images/10/image_0/000939.png
#   inflating: /content/images/10/image_0/000940.png
#   inflating: /content/images/10/image_0/000941.png
#   inflating: /content/images/10/image_0/000942.png
#   inflating: /content/images/10/image_0/000943.png
#   inflating: /content/images/10/image_0/000944.png
#   inflating: /content/images/10/image_0/000945.png
#   inflating: /content/images/10/image_0/000946.png
#   inflating: /content/images/10/image_0/000947.png
#   inflating: /content/images/10/image_0/000948.png
#   inflating: /content/images/10/image_0/000949.png
#   inflating: /content/images/10/image_0/000950.png
#   inflating: /content/images/10/image_0/000951.png
#   inflating: /content/images/10/image_0/000952.png
#   inflating: /content/images/10/image_0/000953.png
#   inflating: /content/images/10/image_0/000954.png
#   inflating: /content/images/10/image_0/000955.png
#   inflating: /content/images/10/image_0/000956.png
#   inflating: /content/images/10/image_0/000957.png
#   inflating: /content/images/10/image_0/000958.png
#   inflating: /content/images/10/image_0/000959.png
#   inflating: /content/images/10/image_0/000960.png
#   inflating: /content/images/10/image_0/000961.png
#   inflating: /content/images/10/image_0/000962.png
#   inflating: /content/images/10/image_0/000963.png
#   inflating: /content/images/10/image_0/000964.png
#   inflating: /content/images/10/image_0/000965.png
#   inflating: /content/images/10/image_0/000966.png
#   inflating: /content/images/10/image_0/000967.png
#   inflating: /content/images/10/image_0/000968.png
#   inflating: /content/images/10/image_0/000969.png
#   inflating: /content/images/10/image_0/000970.png
#   inflating: /content/images/10/image_0/000971.png
#   inflating: /content/images/10/image_0/000972.png
#   inflating: /content/images/10/image_0/000973.png
#   inflating: /content/images/10/image_0/000974.png
#   inflating: /content/images/10/image_0/000975.png
#   inflating: /content/images/10/image_0/000976.png
#   inflating: /content/images/10/image_0/000977.png
#   inflating: /content/images/10/image_0/000978.png
#   inflating: /content/images/10/image_0/000979.png
#   inflating: /content/images/10/image_0/000980.png
#   inflating: /content/images/10/image_0/000981.png
#   inflating: /content/images/10/image_0/000982.png
#   inflating: /content/images/10/image_0/000983.png
#   inflating: /content/images/10/image_0/000984.png
#   inflating: /content/images/10/image_0/000985.png
#   inflating: /content/images/10/image_0/000986.png
#   inflating: /content/images/10/image_0/000987.png
#   inflating: /content/images/10/image_0/000988.png
#   inflating: /content/images/10/image_0/000989.png
#   inflating: /content/images/10/image_0/000990.png
#   inflating: /content/images/10/image_0/000991.png
#   inflating: /content/images/10/image_0/000992.png
#   inflating: /content/images/10/image_0/000993.png
#   inflating: /content/images/10/image_0/000994.png
#   inflating: /content/images/10/image_0/000995.png
#   inflating: /content/images/10/image_0/000996.png
#   inflating: /content/images/10/image_0/000997.png
#   inflating: /content/images/10/image_0/000998.png
#   inflating: /content/images/10/image_0/000999.png
#   inflating: /content/images/10/image_0/001000.png
#   inflating: /content/images/10/image_0/001001.png
#   inflating: /content/images/10/image_0/001002.png
#   inflating: /content/images/10/image_0/001003.png
#   inflating: /content/images/10/image_0/001004.png
#   inflating: /content/images/10/image_0/001005.png
#   inflating: /content/images/10/image_0/001006.png
#   inflating: /content/images/10/image_0/001007.png
#   inflating: /content/images/10/image_0/001008.png
#   inflating: /content/images/10/image_0/001009.png
#   inflating: /content/images/10/image_0/001010.png
#   inflating: /content/images/10/image_0/001011.png
#   inflating: /content/images/10/image_0/001012.png
#   inflating: /content/images/10/image_0/001013.png
#   inflating: /content/images/10/image_0/001014.png
#   inflating: /content/images/10/image_0/001015.png
#   inflating: /content/images/10/image_0/001016.png
#   inflating: /content/images/10/image_0/001017.png
#   inflating: /content/images/10/image_0/001018.png
#   inflating: /content/images/10/image_0/001019.png
#   inflating: /content/images/10/image_0/001020.png
#   inflating: /content/images/10/image_0/001021.png
#   inflating: /content/images/10/image_0/001022.png
#   inflating: /content/images/10/image_0/001023.png
#   inflating: /content/images/10/image_0/001024.png
#   inflating: /content/images/10/image_0/001025.png
#   inflating: /content/images/10/image_0/001026.png
#   inflating: /content/images/10/image_0/001027.png
#   inflating: /content/images/10/image_0/001028.png
#   inflating: /content/images/10/image_0/001029.png
#   inflating: /content/images/10/image_0/001030.png
#   inflating: /content/images/10/image_0/001031.png
#   inflating: /content/images/10/image_0/001032.png
#   inflating: /content/images/10/image_0/001033.png
#   inflating: /content/images/10/image_0/001034.png
#   inflating: /content/images/10/image_0/001035.png
#   inflating: /content/images/10/image_0/001036.png
#   inflating: /content/images/10/image_0/001037.png
#   inflating: /content/images/10/image_0/001038.png
#   inflating: /content/images/10/image_0/001039.png
#   inflating: /content/images/10/image_0/001040.png
#   inflating: /content/images/10/image_0/001041.png
#   inflating: /content/images/10/image_0/001042.png
#   inflating: /content/images/10/image_0/001043.png
#   inflating: /content/images/10/image_0/001044.png
#   inflating: /content/images/10/image_0/001045.png
#   inflating: /content/images/10/image_0/001046.png
#   inflating: /content/images/10/image_0/001047.png
#   inflating: /content/images/10/image_0/001048.png
#   inflating: /content/images/10/image_0/001049.png
#   inflating: /content/images/10/image_0/001050.png
#   inflating: /content/images/10/image_0/001051.png
#   inflating: /content/images/10/image_0/001052.png
#   inflating: /content/images/10/image_0/001053.png
#   inflating: /content/images/10/image_0/001054.png
#   inflating: /content/images/10/image_0/001055.png
#   inflating: /content/images/10/image_0/001056.png
#   inflating: /content/images/10/image_0/001057.png
#   inflating: /content/images/10/image_0/001058.png
#   inflating: /content/images/10/image_0/001059.png
#   inflating: /content/images/10/image_0/001060.png
#   inflating: /content/images/10/image_0/001061.png
#   inflating: /content/images/10/image_0/001062.png
#   inflating: /content/images/10/image_0/001063.png
#   inflating: /content/images/10/image_0/001064.png
#   inflating: /content/images/10/image_0/001065.png
#   inflating: /content/images/10/image_0/001066.png
#   inflating: /content/images/10/image_0/001067.png
#   inflating: /content/images/10/image_0/001068.png
#   inflating: /content/images/10/image_0/001069.png
#   inflating: /content/images/10/image_0/001070.png
#   inflating: /content/images/10/image_0/001071.png
#   inflating: /content/images/10/image_0/001072.png
#   inflating: /content/images/10/image_0/001073.png
#   inflating: /content/images/10/image_0/001074.png
#   inflating: /content/images/10/image_0/001075.png
#   inflating: /content/images/10/image_0/001076.png
#   inflating: /content/images/10/image_0/001077.png
#   inflating: /content/images/10/image_0/001078.png
#   inflating: /content/images/10/image_0/001079.png
#   inflating: /content/images/10/image_0/001080.png
#   inflating: /content/images/10/image_0/001081.png
#   inflating: /content/images/10/image_0/001082.png
#   inflating: /content/images/10/image_0/001083.png
#   inflating: /content/images/10/image_0/001084.png
#   inflating: /content/images/10/image_0/001085.png
#   inflating: /content/images/10/image_0/001086.png
#   inflating: /content/images/10/image_0/001087.png
#   inflating: /content/images/10/image_0/001088.png
#   inflating: /content/images/10/image_0/001089.png
#   inflating: /content/images/10/image_0/001090.png
#   inflating: /content/images/10/image_0/001091.png
#   inflating: /content/images/10/image_0/001092.png
#   inflating: /content/images/10/image_0/001093.png
#   inflating: /content/images/10/image_0/001094.png
#   inflating: /content/images/10/image_0/001095.png
#   inflating: /content/images/10/image_0/001096.png
#   inflating: /content/images/10/image_0/001097.png
#   inflating: /content/images/10/image_0/001098.png
#   inflating: /content/images/10/image_0/001099.png
#   inflating: /content/images/10/image_0/001100.png
#   inflating: /content/images/10/image_0/001101.png
#   inflating: /content/images/10/image_0/001102.png
#   inflating: /content/images/10/image_0/001103.png
#   inflating: /content/images/10/image_0/001104.png
#   inflating: /content/images/10/image_0/001105.png
#   inflating: /content/images/10/image_0/001106.png
#   inflating: /content/images/10/image_0/001107.png
#   inflating: /content/images/10/image_0/001108.png
#   inflating: /content/images/10/image_0/001109.png
#   inflating: /content/images/10/image_0/001110.png
#   inflating: /content/images/10/image_0/001111.png
#   inflating: /content/images/10/image_0/001112.png
#   inflating: /content/images/10/image_0/001113.png
#   inflating: /content/images/10/image_0/001114.png
#   inflating: /content/images/10/image_0/001115.png
#   inflating: /content/images/10/image_0/001116.png
#   inflating: /content/images/10/image_0/001117.png
#   inflating: /content/images/10/image_0/001118.png
#   inflating: /content/images/10/image_0/001119.png
#   inflating: /content/images/10/image_0/001120.png
#   inflating: /content/images/10/image_0/001121.png
#   inflating: /content/images/10/image_0/001122.png
#   inflating: /content/images/10/image_0/001123.png
#   inflating: /content/images/10/image_0/001124.png
#   inflating: /content/images/10/image_0/001125.png
#   inflating: /content/images/10/image_0/001126.png
#   inflating: /content/images/10/image_0/001127.png
#   inflating: /content/images/10/image_0/001128.png
#   inflating: /content/images/10/image_0/001129.png
#   inflating: /content/images/10/image_0/001130.png
#   inflating: /content/images/10/image_0/001131.png
#   inflating: /content/images/10/image_0/001132.png
#   inflating: /content/images/10/image_0/001133.png
#   inflating: /content/images/10/image_0/001134.png
#   inflating: /content/images/10/image_0/001135.png
#   inflating: /content/images/10/image_0/001136.png
#   inflating: /content/images/10/image_0/001137.png
#   inflating: /content/images/10/image_0/001138.png
#   inflating: /content/images/10/image_0/001139.png
#   inflating: /content/images/10/image_0/001140.png
#   inflating: /content/images/10/image_0/001141.png
#   inflating: /content/images/10/image_0/001142.png
#   inflating: /content/images/10/image_0/001143.png
#   inflating: /content/images/10/image_0/001144.png
#   inflating: /content/images/10/image_0/001145.png
#   inflating: /content/images/10/image_0/001146.png
#   inflating: /content/images/10/image_0/001147.png
#   inflating: /content/images/10/image_0/001148.png
#   inflating: /content/images/10/image_0/001149.png
#   inflating: /content/images/10/image_0/001150.png
#   inflating: /content/images/10/image_0/001151.png
#   inflating: /content/images/10/image_0/001152.png
#   inflating: /content/images/10/image_0/001153.png
#   inflating: /content/images/10/image_0/001154.png
#   inflating: /content/images/10/image_0/001155.png
#   inflating: /content/images/10/image_0/001156.png
#   inflating: /content/images/10/image_0/001157.png
#   inflating: /content/images/10/image_0/001158.png
#   inflating: /content/images/10/image_0/001159.png
#   inflating: /content/images/10/image_0/001160.png
#   inflating: /content/images/10/image_0/001161.png
#   inflating: /content/images/10/image_0/001162.png
#   inflating: /content/images/10/image_0/001163.png
#   inflating: /content/images/10/image_0/001164.png
#   inflating: /content/images/10/image_0/001165.png
#   inflating: /content/images/10/image_0/001166.png
#   inflating: /content/images/10/image_0/001167.png
#   inflating: /content/images/10/image_0/001168.png
#   inflating: /content/images/10/image_0/001169.png
#   inflating: /content/images/10/image_0/001170.png
#   inflating: /content/images/10/image_0/001171.png
#   inflating: /content/images/10/image_0/001172.png
#   inflating: /content/images/10/image_0/001173.png
#   inflating: /content/images/10/image_0/001174.png
#   inflating: /content/images/10/image_0/001175.png
#   inflating: /content/images/10/image_0/001176.png
#   inflating: /content/images/10/image_0/001177.png
#   inflating: /content/images/10/image_0/001178.png
#   inflating: /content/images/10/image_0/001179.png
#   inflating: /content/images/10/image_0/001180.png
#   inflating: /content/images/10/image_0/001181.png
#   inflating: /content/images/10/image_0/001182.png
#   inflating: /content/images/10/image_0/001183.png
#   inflating: /content/images/10/image_0/001184.png
#   inflating: /content/images/10/image_0/001185.png
#   inflating: /content/images/10/image_0/001186.png
#   inflating: /content/images/10/image_0/001187.png
#   inflating: /content/images/10/image_0/001188.png
#   inflating: /content/images/10/image_0/001189.png
#   inflating: /content/images/10/image_0/001190.png
#   inflating: /content/images/10/image_0/001191.png
#   inflating: /content/images/10/image_0/001192.png
#   inflating: /content/images/10/image_0/001193.png
#   inflating: /content/images/10/image_0/001194.png
#   inflating: /content/images/10/image_0/001195.png
#   inflating: /content/images/10/image_0/001196.png
#   inflating: /content/images/10/image_0/001197.png
#   inflating: /content/images/10/image_0/001198.png
#   inflating: /content/images/10/image_0/001199.png
#   inflating: /content/images/10/image_0/001200.png
#   inflating: /content/images/10/times.txt

# %%
# !pip install imgaug
# !pip install numpy==1.24.4
# Out:
# Requirement already satisfied: imgaug in /usr/local/lib/python3.11/dist-packages (0.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from imgaug) (1.17.0)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.11/dist-packages (from imgaug) (1.24.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from imgaug) (1.15.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from imgaug) (11.2.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from imgaug) (3.10.0)
# Requirement already satisfied: scikit-image>=0.14.2 in /usr/local/lib/python3.11/dist-packages (from imgaug) (0.25.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from imgaug) (4.11.0.86)
# Requirement already satisfied: imageio in /usr/local/lib/python3.11/dist-packages (from imgaug) (2.37.0)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.11/dist-packages (from imgaug) (2.1.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.14.2->imgaug) (3.4.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.14.2->imgaug) (2025.3.30)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.14.2->imgaug) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.14.2->imgaug) (0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->imgaug) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->imgaug) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->imgaug) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->imgaug) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->imgaug) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->imgaug) (2.9.0.post0)
# Requirement already satisfied: numpy==1.24.4 in /usr/local/lib/python3.11/dist-packages (1.24.4)

# %%
import os
import os.path
from PIL import Image
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import random
from torchvision import transforms
import math
import torch.nn as nn
import torch.nn.functional as F
import time
from torch.amp import autocast, GradScaler
import torchvision.transforms.functional as TF
# import imgaug.augmenters as iaa

# %% [markdown]
# Дата лоадер

# %%
def get_pathes(base_folder ):
    paths = []
    for i in range(11):
        folder_name = f'{i:02d}'
        image_folder = os.path.join(base_folder, folder_name, 'image_0')
        movements_file = os.path.join(base_folder, folder_name, f'{folder_name}.txt')
        paths.append((image_folder,movements_file))
    return paths

def get_data(batch_size, base_folder = '/content/images'):
    paths = get_pathes(base_folder)

    # Вибір папок для тренування, валідації і тестування
    validation_folder = paths[-2]  # Предостання папка
    test_folder = paths[-1]        # Остання папка
    train_folders = paths[:-2]     # Всі інші папки

    # Читання рухання з файлу
    def create_movements(movements_file):
        movements = []
        with open(movements_file, 'r') as f:
            for line in f:
                data = list(map(float, line.strip().split()))
                movements.append(data)
        return movements

    step = 1

    def transform_mov(movements):
        res_movements = []
        # for i in range(len(movements)-1):
        for i in range(len(movements)-step):
            m1 = torch.tensor(movements[i])
            m2 = torch.tensor(movements[i+step])
            res = m2-m1
            distance = math.sqrt(pow(res[3],2) + pow(res[7],2) + pow(res[11],2))
            res_movements.append([distance ])
        return res_movements

    # класс Dataset
    class ImageDataset(Dataset):
        def __init__(self, image_folder, movements, transform=None ):
            # Отримуємо список всіх файлів .png і сортуємо їх
            all_image_files = sorted([os.path.join(image_folder, file) for file in os.listdir(image_folder) if file.endswith('.png')])
            self.image_files = all_image_files
            self.movements = movements
            self.transform = transform

        def __len__(self):
            # Повертаємо мінімальну довжину між рухами та зображеннями - 1
            return min(len(self.movements), len(self.image_files) - 1)


        def __getitem__(self, idx):
            image1_path = self.image_files[idx]
            # image2_path = self.image_files[idx + 1]
            image2_path = self.image_files[idx + step]

            image1 = Image.open(image1_path).convert('L')
            image2 = Image.open(image2_path).convert('L')

            if self.transform:
                image1 = self.transform(image1)
                image2 = self.transform(image2)

            movement = self.movements[idx].clone().detach().float()if isinstance(self.movements[idx], torch.Tensor) else torch.tensor(self.movements[idx], dtype=torch.float32)
            return (image1, image2), movement


    # Трансформації для зменшення використання пам'яті
    transform = transforms.Compose([
        transforms.Grayscale(),
        # transforms.Resize((376,1240)),
        transforms.CenterCrop((370,1226)),
        # transforms.Resize((180,320)),
        transforms.ToTensor()
    ])

    # transform = PairTransform()

    def load_dataset(folders):
        images, movements = [], []
        for image_folder, movements_file in folders:
            mov = create_movements(movements_file)
            mov = transform_mov(mov)
            movements.append(mov)
            images.append(image_folder)
        return images, movements

    train_images, train_movements = load_dataset(train_folders)
    train_dataset = []
    for index,image_folder in enumerate(train_images):
        dataset = ImageDataset(image_folder, train_movements[index], transform=transform)
        train_dataset.append(dataset)
    train_dataset = torch.utils.data.ConcatDataset(train_dataset)

    # Завантаження валідаційних даних
    val_images, val_movements = load_dataset([validation_folder])
    val_dataset = ImageDataset(val_images[0], val_movements[0], transform=transform)


   # Завантаження тестових даних
    test_images, test_movements = load_dataset([test_folder])
    test_dataset = ImageDataset(test_images[0], test_movements[0], transform=transform)

    # DataLoaders
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle = True, num_workers=4, pin_memory=True)
    validation_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle = False, num_workers=4, pin_memory=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle = False, num_workers=4, pin_memory=True)

    return train_loader, validation_loader, test_loader

# %% [markdown]
# EVALUATION

# %%
def set_all_seeds(seed):
    os.environ["PL_GLOBAL_SEED"] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

def compute_accuracy(model, data_loader, device):
    model.eval()
    total_loss = 0.0
    num_batches = 0
    correct_predictions = 0   # Лічильник коректних передбачень
    total_samples = 0         # Загальна кількість елементів

    criterion = torch.nn.MSELoss()

    with torch.no_grad():
        for batch_idx, ((feature1, feature2),targets) in enumerate(data_loader):
            feature1 = feature1.to(device)
            feature2 = feature2.to(device)
            targets = targets.to(device)
            with autocast(device_type='cuda'):
                predicted_y = model(feature1, feature2)

            # Обчислення помилки
            loss = criterion(predicted_y, targets)
            total_loss += loss.item()
            num_batches += 1

            # Перевірка критерію якості
            relative_difference = torch.abs((predicted_y - targets)) # Розрахунок абсолютного відхилення
            valid_predictions = torch.all(relative_difference <= 0.1, dim=1)    # Умова: відхилення <= 10 см
            correct_predictions += torch.sum(valid_predictions).item()
            total_samples = total_samples + targets.size(0)


    avg_loss = total_loss / num_batches             # Розрахунок середньої помилки
    accuracy = correct_predictions / total_samples  # Розрахунок частки вірних передбачень
    return avg_loss, accuracy

def compute_accuracy1(model, data_loader, device):
    model.eval()
    total_loss = 0.0
    num_batches = 0
    correct_predictions = 0   # Лічильник коректних передбачень
    total_samples = 0         # Загальна кількість елементів

    criterion = torch.nn.MSELoss()

    with torch.no_grad():
        for batch_idx, (images,targets) in enumerate(data_loader):
            images = images.to(device)
            targets = targets.to(device)
            with autocast(device_type='cuda'):
                predicted_y = model(images)

            # Обчислення помилки
            loss = criterion(predicted_y, targets)
            total_loss += loss.item()
            num_batches += 1

            # Перевірка критерію якості
            relative_difference = torch.abs((predicted_y - targets)) # Розрахунок абсолютного відхилення
            valid_predictions = torch.all(relative_difference <= 0.1, dim=1)    # Умова: відхилення <= 10 см
            correct_predictions += torch.sum(valid_predictions).item()
            total_samples = total_samples + targets.size(0)


    avg_loss = total_loss / num_batches             # Розрахунок середньої помилки
    accuracy = correct_predictions / total_samples  # Розрахунок частки вірних передбачень
    return avg_loss, accuracy

# %% [markdown]
# Model

# %%
import torch
import torch.nn as nn
from torchvision.models import resnet50, ResNet50_Weights

# %%
class Network(nn.Module):
    def __init__(self):
        super().__init__()

        # Завантажуємо переднавчену модель ResNet50
        weights = ResNet50_Weights.DEFAULT
        base_model = resnet50(weights=weights)

        # Міняжмо перший conv слой для 1-канального зображенняЗ
        self.backbone = nn.Sequential()
        conv1 = nn.Conv2d(2, 64, kernel_size=7, stride=2, padding=3, bias=False)
        # Копіюємо та усереднюємо ваги по каналам
        with torch.no_grad():
            conv1.weight[:] = base_model.conv1.weight.mean(dim=1, keepdim=True)
        self.backbone.add_module("conv1", conv1)

        #Додаємо інші блоки ResNet до avgpool (виключая fc)
        for name, module in list(base_model.named_children())[1:-2]:
            self.backbone.add_module(name, module)

        self.pool = nn.AdaptiveAvgPool2d((1, 3))
        self.lstm = nn.LSTM(input_size=2048 * 3, hidden_size=128, num_layers=1, batch_first=True)

        self.classifier = nn.Linear(128, 1)


    def forward(self,images):# images: [B, 5, 1, H, W]
        B,T,C,H,W = images.shape
        pairs = []
        for t in range(1, T):
            pair = torch.cat((images[:, t-1], images[:, t]), dim=1)  # [B, 2, H, W]
            features = self.backbone(pair)  # [B, 2048, H', W']
            features = self.pool(features)  # [B, 2048, 1, 3]
            features = features.view(B, -1)  # [B, 2048 * 3]
            pairs.append(features)

        seq = torch.stack(pairs, dim=1)  # [B, 4, 2048*3]

        lstm_out, _ = self.lstm(seq)  # [B, 4, 128]
        last_output = lstm_out[:, -1, :]  # [B, 128]
        out = self.classifier(last_output)  # [B, 1]
        return out

# %%
class Network(nn.Module):
    def __init__(self):
        super().__init__()

        # Завантажуємо переднавчену модель ResNet50
        weights = ResNet50_Weights.DEFAULT
        base_model = resnet50(weights=weights)

        # Міняжмо перший conv слой для 1-канального зображенняЗ
        self.backbone = nn.Sequential()
        conv1 = nn.Conv2d(2, 64, kernel_size=7, stride=2, padding=3, bias=False)
        # Копіюємо та усереднюємо ваги по каналам
        with torch.no_grad():
            conv1.weight[:] = base_model.conv1.weight.mean(dim=1, keepdim=True)
        self.backbone.add_module("conv1", conv1)

        #Додаємо інші блоки ResNet до avgpool (виключая fc)
        for name, module in list(base_model.named_children())[1:-2]:
            self.backbone.add_module(name, module)

        self.lstm1 = nn.LSTMCell(input_size = 2048*1*3, hidden_size=128)
        self.lstm2 = nn.LSTMCell(input_size = 128, hidden_size=128)

        self.classifier = nn.Linear(128, 1)


    def forward(self,image1,image2):
          images = torch.cat((image1,image2),dim = 1)

          out_features = self.backbone(images)
          out_features = torch.nn.functional.adaptive_avg_pool2d(out_features, (1,3 ))  # [B, C, 3, 10]
          out_features = out_features.view(out_features.size(0), -1)  # [B, C * 3 * 10]

        #   out_features = torch.flatten(out_features, 1)
          batch_size = out_features.size(0)

          # Ініціалізуємо приховані стани та стани осередків для lstm1
          h_t1 = torch.zeros(batch_size, self.lstm1.hidden_size, device=out_features.device)
          c_t1 = torch.zeros(batch_size, self.lstm1.hidden_size, device=out_features.device)

          # Пропускаємо ознаки першої картинки через lstm1 (один часовий крок)
          h_t1_next, c_t1_next = self.lstm1(out_features, (h_t1, c_t1))

        # Пропускаємо ознаки першої картинки через lstm2 (один часовий крок)
          h_t2_next, c_t2_next = self.lstm2(h_t1_next, (h_t1_next, c_t1_next))

          out = self.classifier(h_t2_next) # [batch_size, 1]
          return out

# %%
class Network(nn.Module):
    def __init__(self):
        super(Network, self).__init__()
        self.conv1 = nn.Conv3d(1, 16, kernel_size=(3, 5, 5), stride=(1, 2, 2), padding=(0, 2, 2))
        self.conv2 = nn.Conv3d(16, 32, kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1))
        self.conv3 = nn.Conv3d(32, 64, kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1))
        with torch.no_grad():
            dummy = torch.zeros(1, 1, 5, 180, 320)
            out = self._forward_conv(dummy)
            self.flatten_size = out.view(1, -1).shape[1]
        # Output size after convs: (B, 64, 1, 46, 153)
        self.fc1 = nn.Linear(self.flatten_size, 512)
        self.fc2 = nn.Linear(512, 1)  # [x, y, z, roll, pitch, yaw]

    def _forward_conv(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        return x

    def forward(self, x):
        x = self._forward_conv(x)
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        return self.fc2(x)

# %%
from torchvision.models import resnet18, ResNet18_Weights

# %%
class CNNBackbone(nn.Module):
    def __init__(self, out_dim=256):
        super().__init__()
        weights = ResNet18_Weights.DEFAULT
        base = resnet18(weights=weights)

        new_conv1 = nn.Conv2d(2, 64, kernel_size=7, stride=2, padding=3, bias=False)
        with torch.no_grad():
            new_conv1.weight[:] = base.conv1.weight.mean(dim=1, keepdim=True)[:, :2, :, :]  # среднее по каналам и обрезка до 2

        base.conv1 = new_conv1

        self.encoder = nn.Sequential(*list(base.children())[:-2]) # without avgpool and fc
        self.conv_proj = nn.Conv2d(512, out_dim, kernel_size=1)    # [B, 512, H/32, W/32] -> [B, out_dim, H/32, W/32]

    def forward(self, x):
        x = self.encoder(x)     # [B, 512, H/32, W/32]
        x = self.conv_proj(x)   # [B, out_dim, H/32, W/32]
        return x

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=1000):
        super().__init__()
        pe = torch.zeros(max_len, d_model)
        pos = torch.arange(0, max_len).unsqueeze(1)
        div = torch.exp(torch.arange(0, d_model, 2) * -(torch.log(torch.tensor(10000.0)) / d_model))
        pe[:, 0::2] = torch.sin(pos * div)
        pe[:, 1::2] = torch.cos(pos * div)
        self.pe = pe.unsqueeze(0)  # [1, max_len, d_model]

    def forward(self, x):
        return x + self.pe[:, :x.size(1)].to(x.device)

class Network(nn.Module):
    def __init__(self, feature_dim=256, num_heads=8, num_layers=4):
        super().__init__()
        self.backbone = CNNBackbone(out_dim=feature_dim)
        self.flatten = nn.Flatten(2)  # [B, C, H, W] -> [B, C, H*W]
        self.transpose = lambda x: x.permute(0, 2, 1)  # -> [B, H*W, C]
        self.pos_embed = PositionalEncoding(d_model=feature_dim)

        encoder_layer = nn.TransformerEncoderLayer(d_model=feature_dim, nhead=num_heads)
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)

        self.pool = nn.AdaptiveAvgPool1d(1)  # [B, N, D] -> [B, D]
        self.regressor = nn.Sequential(
            nn.Linear(feature_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 1)  # (tx, ty, tz, rx, ry, rz)
        )

    def forward(self, image1,image2):
        x = torch.cat((image1,image2),dim = 1)
        B, C, H, W = x.shape  # x: [B, 2, H, W] for 2 RGB images -> stacked
        feat = self.backbone(x)  # [B, D, H', W']
        feat = self.flatten(feat)
        feat = self.transpose(feat)
        feat = self.pos_embed(feat)  # [B, N, D]
        feat = self.transformer(feat)  # [B, N, D]
        pooled = feat.mean(dim=1)  # or self.pool(feat.transpose(1, 2)).squeeze(-1)
        out = self.regressor(pooled)
        return out

# %% [markdown]
# Train

# %%
def train(model, num_epochs, last_epoch, train_loader,
                validation_loader, test_loader,optimizer, device,scheduler,
          checkpoint_dict,scaler):
    start_time = time.time()
    minibatch_loss_list, train_loss_list, valid_loss_list = [] ,[], []
    criterion = torch.nn.MSELoss()

    for epoch in range(last_epoch, num_epochs):
        model.train()
        for batch_idx,((image1,image2),targets) in enumerate(train_loader):
            feature1 = image1.to(device)
            feature2 = image2.to(device)
            # images = images.to(device)
            targets = targets.to(device)

            optimizer.zero_grad()
            # <<< Mixed precision begins
            with autocast(device_type='cuda'):
                predicted_y = model(feature1,feature2)
                loss = criterion(predicted_y, targets)

            #  Зворотній прохід
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            minibatch_loss_list.append(loss.item())
            if batch_idx %100 == 0:
                print(f'Epoch: {epoch+1:03d}/{num_epochs:03d} '
                      f'| Batch {batch_idx:04d}/{len(train_loader):04d} '
                      f'| Loss: {loss:.4f}'
                      f'| Learning rate: {optimizer.param_groups[0]["lr"]}')
        # scheduler.step()
        model.eval()
        with torch.no_grad():
            avg_loss_train, accuracy_train = compute_accuracy(model, train_loader, device)
            avg_loss_val, accuracy_val = compute_accuracy(model, validation_loader, device)
            # scheduler.step( avg_loss_val)
            print(f'Epoch: {epoch+1:03d}/{num_epochs:03d} '
                  f'| Train AVG LOSS: {avg_loss_train: .4f} | Accuracy_train: {accuracy_train: .4f} \n'
                  f'| Validation AVG LOSS: {avg_loss_val: .4f} | Accuracy_val: {accuracy_val: .4f} ')
            train_loss_list.append(avg_loss_train)
            valid_loss_list.append(avg_loss_val)

        scheduler.step()

        # checkpoint = {
        #     'model_state_dict': model.state_dict(),
        #     'optimizer_state_dict': optimizer.state_dict()
        # }

        checkpoint_dict['state_model'] = model.state_dict()
        checkpoint_dict['state_opt'] =  optimizer.state_dict()
        checkpoint_dict[ 'state_scheduler'] = scheduler.state_dict()
        checkpoint_dict['train_loss'] = avg_loss_train
        checkpoint_dict['val_loss'] = avg_loss_val
        checkpoint_dict['train_acc'] = accuracy_train
        checkpoint_dict['val_acc'] =  accuracy_val
        checkpoint_dict['EPOCHS'] = num_epochs
        checkpoint_dict['current_epoch'] = epoch + 1
        checkpoint_dict[ 'learning'] = optimizer.param_groups[0]["lr"]

        path = directory_path + str(epoch + 1) + '_epoch.pth'
        torch.save(checkpoint_dict, path)
        # path = '/content/drive/My Drive/checkpoint_model_3.pth'
        # torch.save(checkpoint, path)

        elapsed = (time.time() - start_time)/60
        print(f'Time elapsed: {elapsed:.2f} min')

    elapsed = (time.time() - start_time)/60
    print(f'Total Training Time: {elapsed:.2f} min')

    avg_loss_test, accuracy_test = compute_accuracy(model, test_loader,device)
    print(f'Test AVG LOSS: {avg_loss_test: .4f} | Accuracy_test: {accuracy_test: .4f}')

    return minibatch_loss_list, train_loss_list, valid_loss_list

# %% [markdown]
# Опис моделі, оптимізатора, шедулера

# %%
txt_model_opt_shed = '''
class CNNBackbone(nn.Module):
    def __init__(self, out_dim=256):
        super().__init__()
        weights = ResNet18_Weights.DEFAULT
        base = resnet18(weights=weights)

        new_conv1 = nn.Conv2d(2, 64, kernel_size=7, stride=2, padding=3, bias=False)
        with torch.no_grad():
            new_conv1.weight[:] = base.conv1.weight.mean(dim=1, keepdim=True)[:, :2, :, :]  # среднее по каналам и обрезка до 2

        base.conv1 = new_conv1

        self.encoder = nn.Sequential(*list(base.children())[:-2]) # without avgpool and fc
        self.conv_proj = nn.Conv2d(512, out_dim, kernel_size=1)    # [B, 512, H/32, W/32] -> [B, out_dim, H/32, W/32]

    def forward(self, x):
        x = self.encoder(x)     # [B, 512, H/32, W/32]
        x = self.conv_proj(x)   # [B, out_dim, H/32, W/32]
        return x

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=1000):
        super().__init__()
        pe = torch.zeros(max_len, d_model)
        pos = torch.arange(0, max_len).unsqueeze(1)
        div = torch.exp(torch.arange(0, d_model, 2) * -(torch.log(torch.tensor(10000.0)) / d_model))
        pe[:, 0::2] = torch.sin(pos * div)
        pe[:, 1::2] = torch.cos(pos * div)
        self.pe = pe.unsqueeze(0)  # [1, max_len, d_model]

    def forward(self, x):
        return x + self.pe[:, :x.size(1)].to(x.device)

class Network(nn.Module):
    def __init__(self, feature_dim=256, num_heads=8, num_layers=4):
        super().__init__()
        self.backbone = CNNBackbone(out_dim=feature_dim)
        self.flatten = nn.Flatten(2)  # [B, C, H, W] -> [B, C, H*W]
        self.transpose = lambda x: x.permute(0, 2, 1)  # -> [B, H*W, C]
        self.pos_embed = PositionalEncoding(d_model=feature_dim)

        encoder_layer = nn.TransformerEncoderLayer(d_model=feature_dim, nhead=num_heads)
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)

        self.pool = nn.AdaptiveAvgPool1d(1)  # [B, N, D] -> [B, D]
        self.regressor = nn.Sequential(
            nn.Linear(feature_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 1)  # (tx, ty, tz, rx, ry, rz)
        )

    def forward(self, image1,image2):
        x = torch.cat((image1,image2),dim = 1)
        B, C, H, W = x.shape  # x: [B, 2, H, W] for 2 RGB images -> stacked
        feat = self.backbone(x)  # [B, D, H', W']
        feat = self.flatten(feat)
        feat = self.transpose(feat)
        feat = self.pos_embed(feat)  # [B, N, D]
        feat = self.transformer(feat)  # [B, N, D]
        pooled = feat.mean(dim=1)  # or self.pool(feat.transpose(1, 2)).squeeze(-1)
        out = self.regressor(pooled)
        return out
optimizer = torch.optim.Adam(model.parameters(), lr = 0.0001)

'''

# %% [markdown]
# Створення бібліотеки для збеження збережень

# %%
directory_path = '/content/drive/My Drive/checpoint/transformer/'

# Перевірка існування директорії
if not os.path.exists(directory_path):
    # Створення директорії
    os.makedirs(directory_path)
    print(f"Директорія {directory_path} була створенна.")
else:
    print(f"Директорія {directory_path} вже існує.")
# Out:
# Директорія /content/drive/My Drive/checpoint/transformer/ була створенна.

# %% [markdown]
# Створення словника для збереження результатів

# %%
checkpoint_dict = {
    'model_description' : txt_model_opt_shed,
    'state_model' : None,
    'state_opt'   : None,
    'state_scheduler' : None,

    'train_loss' :None,
    'val_loss'   : None,
    'best_loss'  : None,
    'train_acc'  : None,
    'val_acc'    : None,

    'EPOCHS'     : None,
    'current_epoch' : None,
    'learning' : None
}

# %% [markdown]
# MAIN

# %%
BATCH_SIZE = 8
RANDOM_SEED = 123
NUM_EPOCHS = 5
last_epoch = 0
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Використовується пристрій: {DEVICE}")
# Out:
# Використовується пристрій: cuda

# %%
from torch.optim.lr_scheduler import StepLR
set_all_seeds(RANDOM_SEED)

model = Network()
model = model.to(DEVICE)
optimizer = torch.optim.Adam(model.parameters(), lr = 0.0001, weight_decay = 0.0001)
# optimizer = torch.optim.Adam(model.parameters(), lr = 0.0001)
train_loader, validation_loader, test_loader = get_data(batch_size = BATCH_SIZE)
# scheduler = StepLR(optimizer, step_size = 4, gamma = 0.3)
scheduler = None
scaler = GradScaler()
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 68.5MB/s]
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/transformer.py:385: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# The model has 16,598,017 trainable parameters
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %%
# Завантаження словника з файлу
path = './3_epoch.pth'
checkpoint = torch.load(path)
if scheduler == None:
    scheduler = StepLR(optimizer, step_size = 1, gamma = 1)
# # Завантаження стану моделі
# save_check = checkpoint['optimizer_state_dict']
# save_check['lr'] = 0.0003
model.load_state_dict( checkpoint['state_model'] )
optimizer.load_state_dict( checkpoint['state_opt'] )
scheduler.load_state_dict( checkpoint['state_scheduler'] )
last_epoch = checkpoint['current_epoch']
# # Завантаження стану оптимізатора
# optimizer.load_state_dict(save_check)

# %%
avg_loss_test, accuracy_test = compute_accuracy1(model, test_loader,DEVICE)
print(f'Test AVG LOSS: {avg_loss_test: .4f} | Accuracy_test: {accuracy_test: .4f}')
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Test AVG LOSS:  0.0524 | Accuracy_test:  0.4565

# %%
if scheduler == None:
    scheduler = StepLR(optimizer, step_size = 1, gamma = 1)
minibatch_loss, train_acc, valid_acc = train(model = model,
            num_epochs = NUM_EPOCHS,
            last_epoch = last_epoch,
            train_loader = train_loader,
            validation_loader = validation_loader,
            test_loader = test_loader,
            optimizer = optimizer,
            device = DEVICE,
            scheduler = scheduler,
            checkpoint_dict = checkpoint_dict,
            scaler = scaler)
# Out:
# Epoch: 001/005 | Batch 0000/2550 | Loss: 0.8137| Learning rate: 0.0001
# Epoch: 001/005 | Batch 0100/2550 | Loss: 0.1917| Learning rate: 0.0001
# Epoch: 001/005 | Batch 0200/2550 | Loss: 0.0437| Learning rate: 0.0001
# Epoch: 001/005 | Batch 0300/2550 | Loss: 0.0160| Learning rate: 0.0001
# Epoch: 001/005 | Batch 0400/2550 | Loss: 0.0596| Learning rate: 0.0001
# Epoch: 001/005 | Batch 0500/2550 | Loss: 0.0196| Learning rate: 0.0001
# Epoch: 001/005 | Batch 0600/2550 | Loss: 0.0158| Learning rate: 0.0001
# Epoch: 001/005 | Batch 0700/2550 | Loss: 0.0112| Learning rate: 0.0001
# Epoch: 001/005 | Batch 0800/2550 | Loss: 0.0349| Learning rate: 0.0001
# Epoch: 001/005 | Batch 0900/2550 | Loss: 0.0209| Learning rate: 0.0001
# Epoch: 001/005 | Batch 1000/2550 | Loss: 0.0165| Learning rate: 0.0001
# Epoch: 001/005 | Batch 1100/2550 | Loss: 0.0127| Learning rate: 0.0001
# Epoch: 001/005 | Batch 1200/2550 | Loss: 0.0030| Learning rate: 0.0001
# Epoch: 001/005 | Batch 1300/2550 | Loss: 0.0238| Learning rate: 0.0001
# Epoch: 001/005 | Batch 1400/2550 | Loss: 0.0282| Learning rate: 0.0001
# Epoch: 001/005 | Batch 1500/2550 | Loss: 0.0169| Learning rate: 0.0001
# Epoch: 001/005 | Batch 1600/2550 | Loss: 0.0151| Learning rate: 0.0001
# Epoch: 001/005 | Batch 1700/2550 | Loss: 0.0095| Learning rate: 0.0001
# Epoch: 001/005 | Batch 1800/2550 | Loss: 0.0093| Learning rate: 0.0001
# Epoch: 001/005 | Batch 1900/2550 | Loss: 0.0047| Learning rate: 0.0001
# Epoch: 001/005 | Batch 2000/2550 | Loss: 0.0026| Learning rate: 0.0001
# Epoch: 001/005 | Batch 2100/2550 | Loss: 0.0040| Learning rate: 0.0001
# Epoch: 001/005 | Batch 2200/2550 | Loss: 0.0193| Learning rate: 0.0001
# Epoch: 001/005 | Batch 2300/2550 | Loss: 0.0073| Learning rate: 0.0001
# Epoch: 001/005 | Batch 2400/2550 | Loss: 0.0078| Learning rate: 0.0001
# Epoch: 001/005 | Batch 2500/2550 | Loss: 0.0066| Learning rate: 0.0001
# Epoch: 001/005 | Train AVG LOSS:  0.0058 | Accuracy_train:  0.8160
# | Validation AVG LOSS:  0.0479 | Accuracy_val:  0.3824
# Time elapsed: 11.40 min
# Epoch: 002/005 | Batch 0000/2550 | Loss: 0.0074| Learning rate: 0.0001
# Epoch: 002/005 | Batch 0100/2550 | Loss: 0.0126| Learning rate: 0.0001
# Epoch: 002/005 | Batch 0200/2550 | Loss: 0.0136| Learning rate: 0.0001
# Epoch: 002/005 | Batch 0300/2550 | Loss: 0.0045| Learning rate: 0.0001
# Epoch: 002/005 | Batch 0400/2550 | Loss: 0.0016| Learning rate: 0.0001
# Epoch: 002/005 | Batch 0500/2550 | Loss: 0.0055| Learning rate: 0.0001
# Epoch: 002/005 | Batch 0600/2550 | Loss: 0.0078| Learning rate: 0.0001
# Epoch: 002/005 | Batch 0700/2550 | Loss: 0.0058| Learning rate: 0.0001
# Epoch: 002/005 | Batch 0800/2550 | Loss: 0.0059| Learning rate: 0.0001
# Epoch: 002/005 | Batch 0900/2550 | Loss: 0.0101| Learning rate: 0.0001
# Epoch: 002/005 | Batch 1000/2550 | Loss: 0.0111| Learning rate: 0.0001
# Epoch: 002/005 | Batch 1100/2550 | Loss: 0.0093| Learning rate: 0.0001
# Epoch: 002/005 | Batch 1200/2550 | Loss: 0.0034| Learning rate: 0.0001
# Epoch: 002/005 | Batch 1300/2550 | Loss: 0.0029| Learning rate: 0.0001
# Epoch: 002/005 | Batch 1400/2550 | Loss: 0.0104| Learning rate: 0.0001
# Epoch: 002/005 | Batch 1500/2550 | Loss: 0.0025| Learning rate: 0.0001
# Epoch: 002/005 | Batch 1600/2550 | Loss: 0.0041| Learning rate: 0.0001
# Epoch: 002/005 | Batch 1700/2550 | Loss: 0.0085| Learning rate: 0.0001
# Epoch: 002/005 | Batch 1800/2550 | Loss: 0.0036| Learning rate: 0.0001
# Epoch: 002/005 | Batch 1900/2550 | Loss: 0.0188| Learning rate: 0.0001
# Epoch: 002/005 | Batch 2000/2550 | Loss: 0.0051| Learning rate: 0.0001
# Epoch: 002/005 | Batch 2100/2550 | Loss: 0.0042| Learning rate: 0.0001
# Epoch: 002/005 | Batch 2200/2550 | Loss: 0.0013| Learning rate: 0.0001
# Epoch: 002/005 | Batch 2300/2550 | Loss: 0.0074| Learning rate: 0.0001
# Epoch: 002/005 | Batch 2400/2550 | Loss: 0.0049| Learning rate: 0.0001
# Epoch: 002/005 | Batch 2500/2550 | Loss: 0.0020| Learning rate: 0.0001
# Epoch: 002/005 | Train AVG LOSS:  0.0125 | Accuracy_train:  0.5622
# | Validation AVG LOSS:  0.0529 | Accuracy_val:  0.3277
# Time elapsed: 22.61 min
# Epoch: 003/005 | Batch 0000/2550 | Loss: 0.0015| Learning rate: 0.0001
# Epoch: 003/005 | Batch 0100/2550 | Loss: 0.0039| Learning rate: 0.0001
# Epoch: 003/005 | Batch 0200/2550 | Loss: 0.0082| Learning rate: 0.0001
# Epoch: 003/005 | Batch 0300/2550 | Loss: 0.0054| Learning rate: 0.0001
# Epoch: 003/005 | Batch 0400/2550 | Loss: 0.0098| Learning rate: 0.0001
# Epoch: 003/005 | Batch 0500/2550 | Loss: 0.0062| Learning rate: 0.0001
# Epoch: 003/005 | Batch 0600/2550 | Loss: 0.0051| Learning rate: 0.0001
# Epoch: 003/005 | Batch 0700/2550 | Loss: 0.0028| Learning rate: 0.0001
# Epoch: 003/005 | Batch 0800/2550 | Loss: 0.0052| Learning rate: 0.0001
# Epoch: 003/005 | Batch 0900/2550 | Loss: 0.0027| Learning rate: 0.0001
# Epoch: 003/005 | Batch 1000/2550 | Loss: 0.0014| Learning rate: 0.0001
# Epoch: 003/005 | Batch 1100/2550 | Loss: 0.0039| Learning rate: 0.0001
# Epoch: 003/005 | Batch 1200/2550 | Loss: 0.0042| Learning rate: 0.0001
# Epoch: 003/005 | Batch 1300/2550 | Loss: 0.0052| Learning rate: 0.0001
# Epoch: 003/005 | Batch 1400/2550 | Loss: 0.0037| Learning rate: 0.0001
# Epoch: 003/005 | Batch 1500/2550 | Loss: 0.0113| Learning rate: 0.0001
# Epoch: 003/005 | Batch 1600/2550 | Loss: 0.0052| Learning rate: 0.0001
# Epoch: 003/005 | Batch 1700/2550 | Loss: 0.0051| Learning rate: 0.0001
# Epoch: 003/005 | Batch 1800/2550 | Loss: 0.0061| Learning rate: 0.0001
# Epoch: 003/005 | Batch 1900/2550 | Loss: 0.0028| Learning rate: 0.0001
# Epoch: 003/005 | Batch 2000/2550 | Loss: 0.0017| Learning rate: 0.0001
# Epoch: 003/005 | Batch 2100/2550 | Loss: 0.0027| Learning rate: 0.0001
# Epoch: 003/005 | Batch 2200/2550 | Loss: 0.0035| Learning rate: 0.0001
# Epoch: 003/005 | Batch 2300/2550 | Loss: 0.0068| Learning rate: 0.0001
# Epoch: 003/005 | Batch 2400/2550 | Loss: 0.0035| Learning rate: 0.0001
# Epoch: 003/005 | Batch 2500/2550 | Loss: 0.0036| Learning rate: 0.0001
# Epoch: 003/005 | Train AVG LOSS:  0.0050 | Accuracy_train:  0.8523
# | Validation AVG LOSS:  0.0501 | Accuracy_val:  0.3245
# Time elapsed: 33.65 min
# Epoch: 004/005 | Batch 0000/2550 | Loss: 0.0051| Learning rate: 0.0001
# Epoch: 004/005 | Batch 0100/2550 | Loss: 0.0008| Learning rate: 0.0001
# Epoch: 004/005 | Batch 0200/2550 | Loss: 0.0013| Learning rate: 0.0001
# Epoch: 004/005 | Batch 0300/2550 | Loss: 0.0030| Learning rate: 0.0001
# Epoch: 004/005 | Batch 0400/2550 | Loss: 0.0043| Learning rate: 0.0001
# Epoch: 004/005 | Batch 0500/2550 | Loss: 0.0026| Learning rate: 0.0001
# Epoch: 004/005 | Batch 0600/2550 | Loss: 0.0035| Learning rate: 0.0001
# Epoch: 004/005 | Batch 0700/2550 | Loss: 0.0016| Learning rate: 0.0001
# Epoch: 004/005 | Batch 0800/2550 | Loss: 0.0029| Learning rate: 0.0001
# Epoch: 004/005 | Batch 0900/2550 | Loss: 0.0028| Learning rate: 0.0001
# Epoch: 004/005 | Batch 1000/2550 | Loss: 0.0019| Learning rate: 0.0001
# Epoch: 004/005 | Batch 1100/2550 | Loss: 0.0016| Learning rate: 0.0001
# Epoch: 004/005 | Batch 1200/2550 | Loss: 0.0034| Learning rate: 0.0001
# Epoch: 004/005 | Batch 1300/2550 | Loss: 0.0012| Learning rate: 0.0001
# Epoch: 004/005 | Batch 1400/2550 | Loss: 0.0095| Learning rate: 0.0001
# Epoch: 004/005 | Batch 1500/2550 | Loss: 0.0068| Learning rate: 0.0001
# Epoch: 004/005 | Batch 1600/2550 | Loss: 0.0015| Learning rate: 0.0001
# Epoch: 004/005 | Batch 1700/2550 | Loss: 0.0036| Learning rate: 0.0001
# Epoch: 004/005 | Batch 1800/2550 | Loss: 0.0013| Learning rate: 0.0001
# Epoch: 004/005 | Batch 1900/2550 | Loss: 0.0029| Learning rate: 0.0001
# Epoch: 004/005 | Batch 2000/2550 | Loss: 0.0083| Learning rate: 0.0001
# Epoch: 004/005 | Batch 2100/2550 | Loss: 0.0039| Learning rate: 0.0001
# Epoch: 004/005 | Batch 2200/2550 | Loss: 0.0022| Learning rate: 0.0001
# Epoch: 004/005 | Batch 2300/2550 | Loss: 0.0019| Learning rate: 0.0001
# Epoch: 004/005 | Batch 2400/2550 | Loss: 0.0034| Learning rate: 0.0001
# Epoch: 004/005 | Batch 2500/2550 | Loss: 0.0012| Learning rate: 0.0001
# Epoch: 004/005 | Train AVG LOSS:  0.0037 | Accuracy_train:  0.9045
# | Validation AVG LOSS:  0.0437 | Accuracy_val:  0.3409
# Time elapsed: 44.80 min
# Epoch: 005/005 | Batch 0000/2550 | Loss: 0.0034| Learning rate: 0.0001
# Epoch: 005/005 | Batch 0100/2550 | Loss: 0.0008| Learning rate: 0.0001
# Epoch: 005/005 | Batch 0200/2550 | Loss: 0.0017| Learning rate: 0.0001
# Epoch: 005/005 | Batch 0300/2550 | Loss: 0.0017| Learning rate: 0.0001
# Epoch: 005/005 | Batch 0400/2550 | Loss: 0.0012| Learning rate: 0.0001
# Epoch: 005/005 | Batch 0500/2550 | Loss: 0.0012| Learning rate: 0.0001
# Epoch: 005/005 | Batch 0600/2550 | Loss: 0.0049| Learning rate: 0.0001
# Epoch: 005/005 | Batch 0700/2550 | Loss: 0.0090| Learning rate: 0.0001
# Epoch: 005/005 | Batch 0800/2550 | Loss: 0.0020| Learning rate: 0.0001
# Epoch: 005/005 | Batch 0900/2550 | Loss: 0.0054| Learning rate: 0.0001
# Epoch: 005/005 | Batch 1000/2550 | Loss: 0.0057| Learning rate: 0.0001
# Epoch: 005/005 | Batch 1100/2550 | Loss: 0.0029| Learning rate: 0.0001
# Epoch: 005/005 | Batch 1200/2550 | Loss: 0.0059| Learning rate: 0.0001
# Epoch: 005/005 | Batch 1300/2550 | Loss: 0.0019| Learning rate: 0.0001
# Epoch: 005/005 | Batch 1400/2550 | Loss: 0.0013| Learning rate: 0.0001
# Epoch: 005/005 | Batch 1500/2550 | Loss: 0.0008| Learning rate: 0.0001
# Epoch: 005/005 | Batch 1600/2550 | Loss: 0.0009| Learning rate: 0.0001
# Epoch: 005/005 | Batch 1700/2550 | Loss: 0.0033| Learning rate: 0.0001
# Epoch: 005/005 | Batch 1800/2550 | Loss: 0.0030| Learning rate: 0.0001
# Epoch: 005/005 | Batch 1900/2550 | Loss: 0.0023| Learning rate: 0.0001
# Epoch: 005/005 | Batch 2000/2550 | Loss: 0.0034| Learning rate: 0.0001
# Epoch: 005/005 | Batch 2100/2550 | Loss: 0.0035| Learning rate: 0.0001
# Epoch: 005/005 | Batch 2200/2550 | Loss: 0.0048| Learning rate: 0.0001
# Epoch: 005/005 | Batch 2300/2550 | Loss: 0.0047| Learning rate: 0.0001
# Epoch: 005/005 | Batch 2400/2550 | Loss: 0.0017| Learning rate: 0.0001
# Epoch: 005/005 | Batch 2500/2550 | Loss: 0.0063| Learning rate: 0.0001
# Epoch: 005/005 | Train AVG LOSS:  0.0037 | Accuracy_train:  0.9179
# | Validation AVG LOSS:  0.0378 | Accuracy_val:  0.3836
# Time elapsed: 56.24 min
# Total Training Time: 56.24 min
# Test AVG LOSS:  0.0605 | Accuracy_test:  0.3933

# %%
if scheduler == None:
    scheduler = StepLR(optimizer, step_size = 1, gamma = 1)
minibatch_loss, train_acc, valid_acc = train(model = model,
            num_epochs = 10,
            last_epoch = 5,
            train_loader = train_loader,
            validation_loader = validation_loader,
            test_loader = test_loader,
            optimizer = optimizer,
            device = DEVICE,
            scheduler = scheduler,
            checkpoint_dict = checkpoint_dict,
            scaler = scaler)
# Out:
# Epoch: 006/010 | Batch 0000/2550 | Loss: 0.0027| Learning rate: 0.0001
# Epoch: 006/010 | Batch 0100/2550 | Loss: 0.0014| Learning rate: 0.0001
# Epoch: 006/010 | Batch 0200/2550 | Loss: 0.0036| Learning rate: 0.0001
# Epoch: 006/010 | Batch 0300/2550 | Loss: 0.0022| Learning rate: 0.0001
# Epoch: 006/010 | Batch 0400/2550 | Loss: 0.0016| Learning rate: 0.0001
# Epoch: 006/010 | Batch 0500/2550 | Loss: 0.0049| Learning rate: 0.0001
# Epoch: 006/010 | Batch 0600/2550 | Loss: 0.0017| Learning rate: 0.0001
# Epoch: 006/010 | Batch 0700/2550 | Loss: 0.0019| Learning rate: 0.0001
# Epoch: 006/010 | Batch 0800/2550 | Loss: 0.0015| Learning rate: 0.0001
# Epoch: 006/010 | Batch 0900/2550 | Loss: 0.0018| Learning rate: 0.0001
# Epoch: 006/010 | Batch 1000/2550 | Loss: 0.0029| Learning rate: 0.0001
# Epoch: 006/010 | Batch 1100/2550 | Loss: 0.0021| Learning rate: 0.0001
# Epoch: 006/010 | Batch 1200/2550 | Loss: 0.0021| Learning rate: 0.0001
# Epoch: 006/010 | Batch 1300/2550 | Loss: 0.0023| Learning rate: 0.0001
# Epoch: 006/010 | Batch 1400/2550 | Loss: 0.0041| Learning rate: 0.0001
# Epoch: 006/010 | Batch 1500/2550 | Loss: 0.0020| Learning rate: 0.0001
# Epoch: 006/010 | Batch 1600/2550 | Loss: 0.0024| Learning rate: 0.0001
# Epoch: 006/010 | Batch 1700/2550 | Loss: 0.0020| Learning rate: 0.0001
# Epoch: 006/010 | Batch 1800/2550 | Loss: 0.0019| Learning rate: 0.0001
# Epoch: 006/010 | Batch 1900/2550 | Loss: 0.0018| Learning rate: 0.0001
# Epoch: 006/010 | Batch 2000/2550 | Loss: 0.0011| Learning rate: 0.0001
# Epoch: 006/010 | Batch 2100/2550 | Loss: 0.0032| Learning rate: 0.0001
# Epoch: 006/010 | Batch 2200/2550 | Loss: 0.0022| Learning rate: 0.0001
# Epoch: 006/010 | Batch 2300/2550 | Loss: 0.0035| Learning rate: 0.0001
# Epoch: 006/010 | Batch 2400/2550 | Loss: 0.0007| Learning rate: 0.0001
# Epoch: 006/010 | Batch 2500/2550 | Loss: 0.0047| Learning rate: 0.0001
# Epoch: 006/010 | Train AVG LOSS:  0.0062 | Accuracy_train:  0.8215
# | Validation AVG LOSS:  0.0469 | Accuracy_val:  0.3830
# Time elapsed: 11.00 min
# Epoch: 007/010 | Batch 0000/2550 | Loss: 0.0017| Learning rate: 0.0001
# Epoch: 007/010 | Batch 0100/2550 | Loss: 0.0017| Learning rate: 0.0001
# Epoch: 007/010 | Batch 0200/2550 | Loss: 0.0014| Learning rate: 0.0001
# Epoch: 007/010 | Batch 0300/2550 | Loss: 0.0005| Learning rate: 0.0001
# Epoch: 007/010 | Batch 0400/2550 | Loss: 0.0025| Learning rate: 0.0001
# Epoch: 007/010 | Batch 0500/2550 | Loss: 0.0064| Learning rate: 0.0001
# Epoch: 007/010 | Batch 0600/2550 | Loss: 0.0042| Learning rate: 0.0001
# Epoch: 007/010 | Batch 0700/2550 | Loss: 0.0080| Learning rate: 0.0001
# Epoch: 007/010 | Batch 0800/2550 | Loss: 0.0016| Learning rate: 0.0001
# Epoch: 007/010 | Batch 0900/2550 | Loss: 0.0002| Learning rate: 0.0001
# Epoch: 007/010 | Batch 1000/2550 | Loss: 0.0014| Learning rate: 0.0001
# Epoch: 007/010 | Batch 1100/2550 | Loss: 0.0004| Learning rate: 0.0001
# Epoch: 007/010 | Batch 1200/2550 | Loss: 0.0018| Learning rate: 0.0001
# Epoch: 007/010 | Batch 1300/2550 | Loss: 0.0019| Learning rate: 0.0001
# Epoch: 007/010 | Batch 1400/2550 | Loss: 0.0013| Learning rate: 0.0001
# Epoch: 007/010 | Batch 1500/2550 | Loss: 0.0014| Learning rate: 0.0001
# Epoch: 007/010 | Batch 1600/2550 | Loss: 0.0006| Learning rate: 0.0001
# Epoch: 007/010 | Batch 1700/2550 | Loss: 0.0021| Learning rate: 0.0001
# Epoch: 007/010 | Batch 1800/2550 | Loss: 0.0014| Learning rate: 0.0001
# Epoch: 007/010 | Batch 1900/2550 | Loss: 0.0050| Learning rate: 0.0001
# Epoch: 007/010 | Batch 2000/2550 | Loss: 0.0016| Learning rate: 0.0001
# Epoch: 007/010 | Batch 2100/2550 | Loss: 0.0019| Learning rate: 0.0001
# Epoch: 007/010 | Batch 2200/2550 | Loss: 0.0037| Learning rate: 0.0001
# Epoch: 007/010 | Batch 2300/2550 | Loss: 0.0012| Learning rate: 0.0001
# Epoch: 007/010 | Batch 2400/2550 | Loss: 0.0020| Learning rate: 0.0001
# Epoch: 007/010 | Batch 2500/2550 | Loss: 0.0012| Learning rate: 0.0001
# Epoch: 007/010 | Train AVG LOSS:  0.0081 | Accuracy_train:  0.7412
# | Validation AVG LOSS:  0.0569 | Accuracy_val:  0.3843
# Time elapsed: 21.94 min
# Epoch: 008/010 | Batch 0000/2550 | Loss: 0.0024| Learning rate: 0.0001
# Epoch: 008/010 | Batch 0100/2550 | Loss: 0.0015| Learning rate: 0.0001
# Epoch: 008/010 | Batch 0200/2550 | Loss: 0.0004| Learning rate: 0.0001
# Epoch: 008/010 | Batch 0300/2550 | Loss: 0.0009| Learning rate: 0.0001
# Epoch: 008/010 | Batch 0400/2550 | Loss: 0.0012| Learning rate: 0.0001
# Epoch: 008/010 | Batch 0500/2550 | Loss: 0.0020| Learning rate: 0.0001
# Epoch: 008/010 | Batch 0600/2550 | Loss: 0.0039| Learning rate: 0.0001
# Epoch: 008/010 | Batch 0700/2550 | Loss: 0.0002| Learning rate: 0.0001
# Epoch: 008/010 | Batch 0800/2550 | Loss: 0.0009| Learning rate: 0.0001
# Epoch: 008/010 | Batch 0900/2550 | Loss: 0.0010| Learning rate: 0.0001
# Epoch: 008/010 | Batch 1000/2550 | Loss: 0.0008| Learning rate: 0.0001
# Epoch: 008/010 | Batch 1100/2550 | Loss: 0.0023| Learning rate: 0.0001
# Epoch: 008/010 | Batch 1200/2550 | Loss: 0.0042| Learning rate: 0.0001
# Epoch: 008/010 | Batch 1300/2550 | Loss: 0.0049| Learning rate: 0.0001
# Epoch: 008/010 | Batch 1400/2550 | Loss: 0.0019| Learning rate: 0.0001
# Epoch: 008/010 | Batch 1500/2550 | Loss: 0.0006| Learning rate: 0.0001
# Epoch: 008/010 | Batch 1600/2550 | Loss: 0.0017| Learning rate: 0.0001
# Epoch: 008/010 | Batch 1700/2550 | Loss: 0.0024| Learning rate: 0.0001
# Epoch: 008/010 | Batch 1800/2550 | Loss: 0.0019| Learning rate: 0.0001
# Epoch: 008/010 | Batch 1900/2550 | Loss: 0.0011| Learning rate: 0.0001
# Epoch: 008/010 | Batch 2000/2550 | Loss: 0.0006| Learning rate: 0.0001
# Epoch: 008/010 | Batch 2100/2550 | Loss: 0.0015| Learning rate: 0.0001
# Epoch: 008/010 | Batch 2200/2550 | Loss: 0.0019| Learning rate: 0.0001
# Epoch: 008/010 | Batch 2300/2550 | Loss: 0.0011| Learning rate: 0.0001
# Epoch: 008/010 | Batch 2400/2550 | Loss: 0.0026| Learning rate: 0.0001
# Epoch: 008/010 | Batch 2500/2550 | Loss: 0.0011| Learning rate: 0.0001
# Epoch: 008/010 | Train AVG LOSS:  0.0031 | Accuracy_train:  0.9338
# | Validation AVG LOSS:  0.0465 | Accuracy_val:  0.4019
# Time elapsed: 32.71 min
# Epoch: 009/010 | Batch 0000/2550 | Loss: 0.0014| Learning rate: 0.0001
# Epoch: 009/010 | Batch 0100/2550 | Loss: 0.0025| Learning rate: 0.0001
# Epoch: 009/010 | Batch 0200/2550 | Loss: 0.0016| Learning rate: 0.0001
# Epoch: 009/010 | Batch 0300/2550 | Loss: 0.0004| Learning rate: 0.0001
# Epoch: 009/010 | Batch 0400/2550 | Loss: 0.0009| Learning rate: 0.0001
# Epoch: 009/010 | Batch 0500/2550 | Loss: 0.0009| Learning rate: 0.0001
# Epoch: 009/010 | Batch 0600/2550 | Loss: 0.0012| Learning rate: 0.0001
# Epoch: 009/010 | Batch 0700/2550 | Loss: 0.0007| Learning rate: 0.0001
# Epoch: 009/010 | Batch 0800/2550 | Loss: 0.0022| Learning rate: 0.0001
# Epoch: 009/010 | Batch 0900/2550 | Loss: 0.0011| Learning rate: 0.0001
# Epoch: 009/010 | Batch 1000/2550 | Loss: 0.0012| Learning rate: 0.0001
# Epoch: 009/010 | Batch 1100/2550 | Loss: 0.0001| Learning rate: 0.0001
# Epoch: 009/010 | Batch 1200/2550 | Loss: 0.0002| Learning rate: 0.0001
# Epoch: 009/010 | Batch 1300/2550 | Loss: 0.0011| Learning rate: 0.0001
# Epoch: 009/010 | Batch 1400/2550 | Loss: 0.0011| Learning rate: 0.0001
# Epoch: 009/010 | Batch 1500/2550 | Loss: 0.0016| Learning rate: 0.0001
# Epoch: 009/010 | Batch 1600/2550 | Loss: 0.0013| Learning rate: 0.0001
# Epoch: 009/010 | Batch 1700/2550 | Loss: 0.0014| Learning rate: 0.0001
# Epoch: 009/010 | Batch 1800/2550 | Loss: 0.0008| Learning rate: 0.0001
# Epoch: 009/010 | Batch 1900/2550 | Loss: 0.0010| Learning rate: 0.0001
# Epoch: 009/010 | Batch 2000/2550 | Loss: 0.0010| Learning rate: 0.0001
# Epoch: 009/010 | Batch 2100/2550 | Loss: 0.0016| Learning rate: 0.0001
# Epoch: 009/010 | Batch 2200/2550 | Loss: 0.0010| Learning rate: 0.0001
# Epoch: 009/010 | Batch 2300/2550 | Loss: 0.0007| Learning rate: 0.0001
# Epoch: 009/010 | Batch 2400/2550 | Loss: 0.0010| Learning rate: 0.0001
# Epoch: 009/010 | Batch 2500/2550 | Loss: 0.0005| Learning rate: 0.0001
# Epoch: 009/010 | Train AVG LOSS:  0.0037 | Accuracy_train:  0.9229
# | Validation AVG LOSS:  0.0547 | Accuracy_val:  0.3642
# Time elapsed: 43.57 min
# Epoch: 010/010 | Batch 0000/2550 | Loss: 0.0004| Learning rate: 0.0001
# Epoch: 010/010 | Batch 0100/2550 | Loss: 0.0016| Learning rate: 0.0001
# Epoch: 010/010 | Batch 0200/2550 | Loss: 0.0005| Learning rate: 0.0001
# Epoch: 010/010 | Batch 0300/2550 | Loss: 0.0003| Learning rate: 0.0001
# Epoch: 010/010 | Batch 0400/2550 | Loss: 0.0006| Learning rate: 0.0001
# Epoch: 010/010 | Batch 0500/2550 | Loss: 0.0005| Learning rate: 0.0001
# Epoch: 010/010 | Batch 0600/2550 | Loss: 0.0009| Learning rate: 0.0001
# Epoch: 010/010 | Batch 0700/2550 | Loss: 0.0006| Learning rate: 0.0001
# Epoch: 010/010 | Batch 0800/2550 | Loss: 0.0015| Learning rate: 0.0001
# Epoch: 010/010 | Batch 0900/2550 | Loss: 0.0021| Learning rate: 0.0001
# Epoch: 010/010 | Batch 1000/2550 | Loss: 0.0026| Learning rate: 0.0001
# Epoch: 010/010 | Batch 1100/2550 | Loss: 0.0021| Learning rate: 0.0001
# Epoch: 010/010 | Batch 1200/2550 | Loss: 0.0012| Learning rate: 0.0001
# Epoch: 010/010 | Batch 1300/2550 | Loss: 0.0005| Learning rate: 0.0001
# Epoch: 010/010 | Batch 1400/2550 | Loss: 0.0010| Learning rate: 0.0001
# Epoch: 010/010 | Batch 1500/2550 | Loss: 0.0038| Learning rate: 0.0001
# Epoch: 010/010 | Batch 1600/2550 | Loss: 0.0017| Learning rate: 0.0001
# Epoch: 010/010 | Batch 1700/2550 | Loss: 0.0009| Learning rate: 0.0001
# Epoch: 010/010 | Batch 1800/2550 | Loss: 0.0012| Learning rate: 0.0001
# Epoch: 010/010 | Batch 1900/2550 | Loss: 0.0010| Learning rate: 0.0001
# Epoch: 010/010 | Batch 2000/2550 | Loss: 0.0006| Learning rate: 0.0001
# Epoch: 010/010 | Batch 2100/2550 | Loss: 0.0001| Learning rate: 0.0001
# Epoch: 010/010 | Batch 2200/2550 | Loss: 0.0004| Learning rate: 0.0001
# Epoch: 010/010 | Batch 2300/2550 | Loss: 0.0021| Learning rate: 0.0001
# Epoch: 010/010 | Batch 2400/2550 | Loss: 0.0006| Learning rate: 0.0001
# Epoch: 010/010 | Batch 2500/2550 | Loss: 0.0009| Learning rate: 0.0001
# Epoch: 010/010 | Train AVG LOSS:  0.0041 | Accuracy_train:  0.9164
# | Validation AVG LOSS:  0.0423 | Accuracy_val:  0.4000
# Time elapsed: 54.29 min
# Total Training Time: 54.29 min
# Test AVG LOSS:  0.0594 | Accuracy_test:  0.3425

# %%
if scheduler == None:
    scheduler = StepLR(optimizer, step_size = 1, gamma = 1)
minibatch_loss, train_acc, valid_acc = train(model = model,
            num_epochs = 8,
            last_epoch = 5,
            train_loader = train_loader,
            validation_loader = validation_loader,
            test_loader = test_loader,
            optimizer = optimizer,
            device = DEVICE,
            scheduler = scheduler,
            checkpoint_dict = checkpoint_dict,
            scaler = scaler)
# Out:
# Epoch: 006/008 | Batch 0000/2546 | Loss: 0.0018| Learning rate: 0.0001
# Epoch: 006/008 | Batch 0100/2546 | Loss: 0.0037| Learning rate: 0.0001
# Epoch: 006/008 | Batch 0200/2546 | Loss: 0.0009| Learning rate: 0.0001
# Epoch: 006/008 | Batch 0300/2546 | Loss: 0.0005| Learning rate: 0.0001
# Epoch: 006/008 | Batch 0400/2546 | Loss: 0.0009| Learning rate: 0.0001
# Epoch: 006/008 | Batch 0500/2546 | Loss: 0.0013| Learning rate: 0.0001
# Epoch: 006/008 | Batch 0600/2546 | Loss: 0.0016| Learning rate: 0.0001
# Epoch: 006/008 | Batch 0700/2546 | Loss: 0.0008| Learning rate: 0.0001
# Epoch: 006/008 | Batch 0800/2546 | Loss: 0.0010| Learning rate: 0.0001
# Epoch: 006/008 | Batch 0900/2546 | Loss: 0.0019| Learning rate: 0.0001
# Epoch: 006/008 | Batch 1000/2546 | Loss: 0.0012| Learning rate: 0.0001
# Epoch: 006/008 | Batch 1100/2546 | Loss: 0.0011| Learning rate: 0.0001
# Epoch: 006/008 | Batch 1200/2546 | Loss: 0.0012| Learning rate: 0.0001
# Epoch: 006/008 | Batch 1300/2546 | Loss: 0.0080| Learning rate: 0.0001
# Epoch: 006/008 | Batch 1400/2546 | Loss: 0.0013| Learning rate: 0.0001
# Epoch: 006/008 | Batch 1500/2546 | Loss: 0.0008| Learning rate: 0.0001
# Epoch: 006/008 | Batch 1600/2546 | Loss: 0.0027| Learning rate: 0.0001
# Epoch: 006/008 | Batch 1700/2546 | Loss: 0.0010| Learning rate: 0.0001
# Epoch: 006/008 | Batch 1800/2546 | Loss: 0.0022| Learning rate: 0.0001
# Epoch: 006/008 | Batch 1900/2546 | Loss: 0.0028| Learning rate: 0.0001
# Epoch: 006/008 | Batch 2000/2546 | Loss: 0.0009| Learning rate: 0.0001
# Epoch: 006/008 | Batch 2100/2546 | Loss: 0.0018| Learning rate: 0.0001
# Epoch: 006/008 | Batch 2200/2546 | Loss: 0.0036| Learning rate: 0.0001
# Epoch: 006/008 | Batch 2300/2546 | Loss: 0.0034| Learning rate: 0.0001
# Epoch: 006/008 | Batch 2400/2546 | Loss: 0.0008| Learning rate: 0.0001
# Epoch: 006/008 | Batch 2500/2546 | Loss: 0.0017| Learning rate: 0.0001
# Epoch: 006/008 | Train AVG LOSS:  0.0018 | Accuracy_train:  0.9703
# | Validation AVG LOSS:  0.0500 | Accuracy_val:  0.3632
# Time elapsed: 18.17 min
# Epoch: 007/008 | Batch 0000/2546 | Loss: 0.0011| Learning rate: 0.0001
# Epoch: 007/008 | Batch 0100/2546 | Loss: 0.0010| Learning rate: 0.0001
# Epoch: 007/008 | Batch 0200/2546 | Loss: 0.0009| Learning rate: 0.0001
# Epoch: 007/008 | Batch 0300/2546 | Loss: 0.0060| Learning rate: 0.0001
# Epoch: 007/008 | Batch 0400/2546 | Loss: 0.0012| Learning rate: 0.0001
# Epoch: 007/008 | Batch 0500/2546 | Loss: 0.0039| Learning rate: 0.0001
# Epoch: 007/008 | Batch 0600/2546 | Loss: 0.0016| Learning rate: 0.0001
# Epoch: 007/008 | Batch 0700/2546 | Loss: 0.0012| Learning rate: 0.0001
# Epoch: 007/008 | Batch 0800/2546 | Loss: 0.0014| Learning rate: 0.0001
# Epoch: 007/008 | Batch 0900/2546 | Loss: 0.0010| Learning rate: 0.0001
# Epoch: 007/008 | Batch 1000/2546 | Loss: 0.0013| Learning rate: 0.0001
# Epoch: 007/008 | Batch 1100/2546 | Loss: 0.0022| Learning rate: 0.0001
# Epoch: 007/008 | Batch 1200/2546 | Loss: 0.0041| Learning rate: 0.0001
# Epoch: 007/008 | Batch 1300/2546 | Loss: 0.0018| Learning rate: 0.0001
# Epoch: 007/008 | Batch 1400/2546 | Loss: 0.0011| Learning rate: 0.0001
# Epoch: 007/008 | Batch 1500/2546 | Loss: 0.0014| Learning rate: 0.0001
# Epoch: 007/008 | Batch 1600/2546 | Loss: 0.0010| Learning rate: 0.0001
# Epoch: 007/008 | Batch 1700/2546 | Loss: 0.0014| Learning rate: 0.0001
# Epoch: 007/008 | Batch 1800/2546 | Loss: 0.0011| Learning rate: 0.0001
# Epoch: 007/008 | Batch 1900/2546 | Loss: 0.0014| Learning rate: 0.0001
# Epoch: 007/008 | Batch 2000/2546 | Loss: 0.0022| Learning rate: 0.0001
# Epoch: 007/008 | Batch 2100/2546 | Loss: 0.0019| Learning rate: 0.0001
# Epoch: 007/008 | Batch 2200/2546 | Loss: 0.0014| Learning rate: 0.0001
# Epoch: 007/008 | Batch 2300/2546 | Loss: 0.0016| Learning rate: 0.0001
# Epoch: 007/008 | Batch 2400/2546 | Loss: 0.0032| Learning rate: 0.0001
# Epoch: 007/008 | Batch 2500/2546 | Loss: 0.0014| Learning rate: 0.0001
# Epoch: 007/008 | Train AVG LOSS:  0.0024 | Accuracy_train:  0.9639
# | Validation AVG LOSS:  0.0465 | Accuracy_val:  0.3676
# Time elapsed: 36.41 min
# Epoch: 008/008 | Batch 0000/2546 | Loss: 0.0035| Learning rate: 0.0001
# Epoch: 008/008 | Batch 0100/2546 | Loss: 0.0017| Learning rate: 0.0001
# Epoch: 008/008 | Batch 0200/2546 | Loss: 0.0030| Learning rate: 0.0001
# Epoch: 008/008 | Batch 0300/2546 | Loss: 0.0025| Learning rate: 0.0001
# Epoch: 008/008 | Batch 0400/2546 | Loss: 0.0017| Learning rate: 0.0001
# Epoch: 008/008 | Batch 0500/2546 | Loss: 0.0057| Learning rate: 0.0001
# Epoch: 008/008 | Batch 0600/2546 | Loss: 0.0014| Learning rate: 0.0001
# Epoch: 008/008 | Batch 0700/2546 | Loss: 0.0006| Learning rate: 0.0001
# Epoch: 008/008 | Batch 0800/2546 | Loss: 0.0004| Learning rate: 0.0001
# Epoch: 008/008 | Batch 0900/2546 | Loss: 0.0028| Learning rate: 0.0001
# Epoch: 008/008 | Batch 1000/2546 | Loss: 0.0010| Learning rate: 0.0001
# Epoch: 008/008 | Batch 1100/2546 | Loss: 0.0018| Learning rate: 0.0001
# Epoch: 008/008 | Batch 1200/2546 | Loss: 0.0007| Learning rate: 0.0001
# Epoch: 008/008 | Batch 1300/2546 | Loss: 0.0014| Learning rate: 0.0001
# Epoch: 008/008 | Batch 1400/2546 | Loss: 0.0005| Learning rate: 0.0001
# Epoch: 008/008 | Batch 1500/2546 | Loss: 0.0019| Learning rate: 0.0001
# Epoch: 008/008 | Batch 1600/2546 | Loss: 0.0031| Learning rate: 0.0001
# Epoch: 008/008 | Batch 1700/2546 | Loss: 0.0003| Learning rate: 0.0001
# Epoch: 008/008 | Batch 1800/2546 | Loss: 0.0012| Learning rate: 0.0001
# Epoch: 008/008 | Batch 1900/2546 | Loss: 0.0011| Learning rate: 0.0001
# Epoch: 008/008 | Batch 2000/2546 | Loss: 0.0018| Learning rate: 0.0001
# Epoch: 008/008 | Batch 2100/2546 | Loss: 0.0005| Learning rate: 0.0001
# Epoch: 008/008 | Batch 2200/2546 | Loss: 0.0006| Learning rate: 0.0001
# Epoch: 008/008 | Batch 2300/2546 | Loss: 0.0032| Learning rate: 0.0001
# Epoch: 008/008 | Batch 2400/2546 | Loss: 0.0016| Learning rate: 0.0001
# Epoch: 008/008 | Batch 2500/2546 | Loss: 0.0020| Learning rate: 0.0001
# Epoch: 008/008 | Train AVG LOSS:  0.0012 | Accuracy_train:  0.9878
# | Validation AVG LOSS:  0.0506 | Accuracy_val:  0.3544
# Time elapsed: 54.71 min
# Total Training Time: 54.71 min
# Test AVG LOSS:  0.0776 | Accuracy_test:  0.3353
